# %% [markdown]
# # Homework 4 - MapReduce
#
# In this homework, we are practicing the MapReduce programming paradigm.
#
# You are required to turn in this notebook as BDM\_HW4\_<b>NetId</b>.ipynb. You will be asked to complete each task using the accompanied <i>mapreduce</i> package (as <b>mapreduce.py</b>) using one or more MapReduce "jobs". For each such job (with mr.run()), you are expected to supply a mapper and a reducer as needed. Below are sample usage of the package:
#
# ```python
#     # Run on input1 using your mapper1 and reducer1 function
#     output = list(mr.run(input1, mapper1, reducer1))
#
#     # Run on input2 using only your mapper2, no reduce phase
#     output = list(mr.run(input2, mapper2))
#
#     # Run on input3 using 2 nested MapReduce jobs
#     output = list(mr.run(mr.run(input3, mapper3, reducer3), mapper4, reducer4))
# ```
#
# Please note that the output the mr.run() is always a <b>generator</b>. You have to cast it to a list if you'd like to view, index or print it out.
#
# We will be using only the citibike data (<b>citibike.csv</b> for this homework.

# %%
import csv
import mapreduce as mr

import pandas as pd
data = pd.read_csv('citibike.csv')
data.columns
# Out:
# Index([u'cartodb_id', u'the_geom', u'tripduration', u'starttime', u'stoptime',
#        u'start_station_id', u'start_station_name', u'start_station_latitude',
#        u'start_station_longitude', u'end_station_id', u'end_station_name',
#        u'end_station_latitude', u'end_station_longitude', u'bikeid',
#        u'usertype', u'birth_year', u'gender'],
#       dtype='object')

# %% [markdown]
# ## Task 1 (2 points)
#
# We would like to write a MapReduce job to count the total number of trips involved at each station. For example, if a trip starts at station A and stops at station B, the trip will count for both A and B. You are asked to fill in the <b>mapper1</b> and <b>reducer1</b> code block. The output must be tuples, each consisting of a station name and a count. A portion of the expected output are included below.

# %%
def mapper1(row):
    for station in [row['start_station_name'], row['end_station_name']]:
        yield (station, 1)
        
    
def reducer1(k2v2):
    station, count = (k2v2)
    return (station, sum(count))
    
with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output1 = list(mr.run(reader, mapper1, reducer1))

output1
# Out:
# [('1 Ave & E 15 St', 795),
#  ('1 Ave & E 44 St', 219),
#  ('10 Ave & W 28 St', 422),
#  ('11 Ave & W 27 St', 354),
#  ('11 Ave & W 41 St', 461),
#  ('11 Ave & W 59 St', 242),
#  ('12 Ave & W 40 St', 217),
#  ('2 Ave & E 31 St', 588),
#  ('2 Ave & E 58 St', 125),
#  ('3 Ave & Schermerhorn St', 34),
#  ('5 Ave & E 29 St', 442),
#  ('6 Ave & Broome St', 227),
#  ('6 Ave & Canal St', 212),
#  ('6 Ave & W 33 St', 517),
#  ('8 Ave & W 31 St', 1065),
#  ('8 Ave & W 33 St', 740),
#  ('8 Ave & W 52 St', 261),
#  ('9 Ave & W 14 St', 245),
#  ('9 Ave & W 16 St', 367),
#  ('9 Ave & W 18 St', 239),
#  ('9 Ave & W 22 St', 570),
#  ('9 Ave & W 45 St', 371),
#  ('Adelphi St & Myrtle Ave', 181),
#  ('Allen St & E Houston St', 418),
#  ('Allen St & Hester St', 309),
#  ('Allen St & Rivington St', 414),
#  ('Ashland Pl & Hanson Pl', 210),
#  ('Atlantic Ave & Fort Greene Pl', 70),
#  ('Atlantic Ave & Furman St', 19),
#  ('Avenue D & E 12 St', 44),
#  ('Avenue D & E 3 St', 224),
#  ('Avenue D & E 8 St', 72),
#  ('Bank St & Hudson St', 308),
#  ('Bank St & Washington St', 230),
#  ('Barclay St & Church St', 500),
#  ('Barrow St & Hudson St', 426),
#  ('Bayard St & Baxter St', 259),
#  ('Bedford Ave & S 9th St', 18),
#  ('Bialystoker Pl & Delancey St', 193),
#  ('Bond St & Schermerhorn St', 100),
#  ('Broad St & Bridge St', 86),
#  ('Broadway & Battery Pl', 220),
#  ('Broadway & Berry St', 21),
#  ('Broadway & E 14 St', 730),
#  ('Broadway & E 22 St', 640),
#  ('Broadway & W 24 St', 642),
#  ('Broadway & W 29 St', 378),
#  ('Broadway & W 32 St', 431),
#  ('Broadway & W 36 St', 299),
#  ('Broadway & W 37 St', 176),
#  ('Broadway & W 39 St', 337),
#  ('Broadway & W 41 St', 432),
#  ('Broadway & W 49 St', 385),
#  ('Broadway & W 51 St', 338),
#  ('Broadway & W 53 St', 197),
#  ('Broadway & W 55 St', 259),
#  ('Broadway & W 58 St', 289),
#  ('Broadway & W 60 St', 405),
#  ('Bus Slip & State St', 94),
#  ('Cadman Plaza E & Red Cross Pl', 30),
#  ('Cadman Plaza E & Tillary St', 40),
#  ('Cadman Plaza West & Montague St', 31),
#  ('Canal St & Rutgers St', 391),
#  ('Carlton Ave & Park Ave', 56),
#  ('Carmine St & 6 Ave', 486),
#  ('Catherine St & Monroe St', 207),
#  ('Central Park S & 6 Ave', 159),
#  ('Centre St & Chambers St', 307),
#  ('Centre St & Worth St', 159),
#  ('Cherry St', 75),
#  ('Christopher St & Greenwich St', 573),
#  ('Clark St & Henry St', 133),
#  ('Clermont Ave & Lafayette Ave', 51),
#  ('Clermont Ave & Park Ave', 76),
#  ('Cleveland Pl & Spring St', 559),
#  ('Cliff St & Fulton St', 167),
#  ('Clinton Ave & Flushing Ave', 33),
#  ('Clinton Ave & Myrtle Ave', 169),
#  ('Clinton St & Grand St', 157),
#  ('Clinton St & Joralemon St', 54),
#  ('Clinton St & Tillary St', 38),
#  ('Columbia Heights & Cranberry St', 20),
#  ('Columbia St & Rivington St', 156),
#  ('Concord St & Bridge St', 50),
#  ('Cumberland St & Lafayette Ave', 73),
#  ('DeKalb Ave & Hudson Ave', 232),
#  ('DeKalb Ave & S Portland Ave', 51),
#  ('DeKalb Ave & Skillman St', 18),
#  ('DeKalb Ave & Vanderbilt Ave', 93),
#  ('Dean St & 4 Ave', 90),
#  ('Division St & Bowery', 319),
#  ('Duane St & Greenwich St', 139),
#  ('Duffield St & Willoughby St', 48),
#  ('E 10 St & 5 Ave', 314),
#  ('E 10 St & Avenue A', 552),
#  ('E 11 St & 1 Ave', 376),
#  ('E 11 St & 2 Ave', 468),
#  ('E 11 St & Broadway', 232),
#  ('E 12 St & 3 Ave', 489),
#  ('E 13 St & Avenue A', 484),
#  ('E 14 St & Avenue B', 507),
#  ('E 15 St & 3 Ave', 380),
#  ('E 16 St & 5 Ave', 498),
#  ('E 16 St & Irving Pl', 309),
#  ('E 17 St & Broadway', 943),
#  ('E 19 St & 3 Ave', 266),
#  ('E 2 St & 2 Ave', 333),
#  ('E 2 St & Avenue B', 397),
#  ('E 2 St & Avenue C', 224),
#  ('E 20 St & 2 Ave', 583),
#  ('E 20 St & FDR Drive', 415),
#  ('E 20 St & Park Ave', 428),
#  ('E 23 St & 1 Ave', 474),
#  ('E 24 St & Park Ave S', 585),
#  ('E 25 St & 1 Ave', 406),
#  ('E 25 St & 2 Ave', 519),
#  ('E 27 St & 1 Ave', 524),
#  ('E 3 St & 1 Ave', 421),
#  ('E 30 St & Park Ave S', 471),
#  ('E 31 St & 3 Ave', 422),
#  ('E 32 St & Park Ave', 600),
#  ('E 33 St & 2 Ave', 654),
#  ('E 33 St & 5 Ave', 411),
#  ('E 37 St & Lexington Ave', 269),
#  ('E 39 St & 2 Ave', 543),
#  ('E 39 St & 3 Ave', 489),
#  ('E 4 St & 2 Ave', 390),
#  ('E 40 St & 5 Ave', 545),
#  ('E 43 St & 2 Ave', 161),
#  ('E 43 St & Vanderbilt Ave', 1003),
#  ('E 45 St & 3 Ave', 265),
#  ('E 47 St & 1 Ave', 104),
#  ('E 47 St & 2 Ave', 235),
#  ('E 47 St & Park Ave', 438),
#  ('E 48 St & 3 Ave', 232),
#  ('E 48 St & Madison Ave', 309),
#  ('E 5 St & Avenue C', 281),
#  ('E 51 St & 1 Ave', 116),
#  ('E 51 St & Lexington Ave', 179),
#  ('E 52 St & 2 Ave', 206),
#  ('E 53 St & Lexington Ave', 201),
#  ('E 53 St & Madison Ave', 214),
#  ('E 55 St & 2 Ave', 156),
#  ('E 55 St & Lexington Ave', 155),
#  ('E 56 St & 3 Ave', 106),
#  ('E 56 St & Madison Ave', 192),
#  ('E 58 St & 3 Ave', 437),
#  ('E 59 St & Sutton Pl', 193),
#  ('E 6 St & Avenue B', 385),
#  ('E 6 St & Avenue D', 177),
#  ('E 7 St & Avenue A', 476),
#  ('E 9 St & Avenue C', 371),
#  ('Elizabeth St & Hester St', 425),
#  ('Emerson Pl & Myrtle Ave', 60),
#  ('FDR Drive & E 35 St', 177),
#  ('Flushing Ave & Carlton Ave', 91),
#  ('Forsyth St & Broome St', 438),
#  ('Forsyth St & Canal St', 209),
#  ('Franklin Ave & Myrtle Ave', 24),
#  ('Franklin St & W Broadway', 141),
#  ('Front St & Gold St', 41),
#  ('Front St & Maiden Ln', 127),
#  ('Front St & Washington St', 106),
#  ('Fulton St & Clermont Ave', 53),
#  ('Fulton St & Grand Ave', 42),
#  ('Fulton St & Rockwell Pl', 76),
#  ('Fulton St & Waverly Ave', 113),
#  ('Fulton St & William St', 232),
#  ('Gallatin Pl & Livingston St', 15),
#  ('Grand Army Plaza & Central Park S', 291),
#  ('Grand St & Greene St', 171),
#  ('Grand St & Havemeyer St', 69),
#  ('Great Jones St', 491),
#  ('Greenwich Ave & 8 Ave', 701),
#  ('Greenwich Ave & Charles St', 284),
#  ('Greenwich St & N Moore St', 305),
#  ('Greenwich St & Warren St', 405),
#  ('Hancock St & Bedford Ave', 18),
#  ('Hanover Pl & Livingston St', 56),
#  ('Harrison St & Hudson St', 118),
#  ('Henry St & Atlantic Ave', 98),
#  ('Henry St & Grand St', 316),
#  ('Henry St & Poplar St', 37),
#  ('Hicks St & Montague St', 128),
#  ('Howard St & Centre St', 267),
#  ('Hudson St & Reade St', 202),
#  ('Jay St & Tech Pl', 136),
#  ('John St & William St', 184),
#  ('Johnson St & Gold St', 103),
#  ('Joralemon St & Adams St', 158),
#  ('Kent Ave & S 11 St', 32),
#  ('LaGuardia Pl & W 3 St', 422),
#  ('Lafayette Ave & Classon Ave', 36),
#  ('Lafayette Ave & Fort Greene Pl', 107),
#  ('Lafayette Ave & St James Pl', 58),
#  ('Lafayette St & E 8 St', 1013),
#  ('Lafayette St & Jersey St', 571),
#  ('Laight St & Hudson St', 78),
#  ('Lawrence St & Willoughby St', 128),
#  ('Lefferts Pl & Franklin Ave', 62),
#  ('Leonard St & Church St', 186),
#  ('Lexington Ave & Classon Ave', 37),
#  ('Lexington Ave & E 24 St', 787),
#  ('Liberty St & Broadway', 260),
#  ('Lispenard St & Broadway', 247),
#  ('Little West St & 1 Pl', 175),
#  ('MacDougal St & Prince St', 543),
#  ('MacDougal St & Washington Sq', 179),
#  ('Macon St & Nostrand Ave', 37),
#  ('Madison St & Clinton St', 220),
#  ('Madison St & Montgomery St', 215),
#  ('Maiden Ln & Pearl St', 225),
#  ('Market St & Cherry St', 99),
#  ('Mercer St & Bleecker St', 547),
#  ('Mercer St & Spring St', 192),
#  ('Metropolitan Ave & Bedford Ave', 120),
#  ('Monroe St & Bedford Ave', 71),
#  ('Monroe St & Classon Ave', 24),
#  ('Mott St & Prince St', 399),
#  ('Murray St & West St', 173),
#  ('Myrtle Ave & St Edwards St', 36),
#  ('Nassau St & Navy St', 12),
#  ('Norfolk St & Broome St', 183),
#  ('Old Fulton St', 41),
#  ('Old Slip & Front St', 121),
#  ('Park Ave & St Edwards St', 39),
#  ('Pearl St & Anchorage Pl', 110),
#  ('Pearl St & Hanover Square', 205),
#  ('Peck Slip & Front St', 174),
#  ('Perry St & Bleecker St', 262),
#  ('Pershing Square North', 605),
#  ('Pershing Square South', 669),
#  ('Pike St & E Broadway', 272),
#  ('Pike St & Monroe St', 105),
#  ('Pitt St & Stanton St', 51),
#  ('Railroad Ave & Kay Ave', 13),
#  ('Reade St & Broadway', 255),
#  ('Rivington St & Chrystie St', 187),
#  ('Rivington St & Ridge St', 135),
#  ('S 3 St & Bedford Ave', 18),
#  ('S 4 St & Wythe Ave', 66),
#  ('S 5 Pl & S 4 St', 91),
#  ('S Portland Ave & Hanson Pl', 66),
#  ('Sands St & Navy St', 14),
#  ('Shevchenko Pl & E 7 St', 358),
#  ('South End Ave & Liberty St', 368),
#  ('South St & Gouverneur Ln', 146),
#  ('South St & Whitehall St', 100),
#  ('Spruce St & Nassau St', 165),
#  ('St James Pl & Oliver St', 131),
#  ('St James Pl & Pearl St', 94),
#  ('St Marks Pl & 1 Ave', 334),
#  ('St Marks Pl & 2 Ave', 496),
#  ('Stanton St & Chrystie St', 269),
#  ('Stanton St & Mangin St', 186),
#  ('State St & Smith St', 124),
#  ('Suffolk St & Stanton St', 417),
#  ('Sullivan St & Washington Sq', 334),
#  ('University Pl & E 14 St', 688),
#  ('Vesey Pl & River Terrace', 432),
#  ('W 11 St & 6 Ave', 218),
#  ('W 13 St & 6 Ave', 543),
#  ('W 13 St & 7 Ave', 364),
#  ('W 14 St & The High Line', 88),
#  ('W 15 St & 7 Ave', 416),
#  ('W 16 St & The High Line', 380),
#  ('W 17 St & 8 Ave', 563),
#  ('W 18 St & 6 Ave', 667),
#  ('W 20 St & 11 Ave', 645),
#  ('W 20 St & 7 Ave', 392),
#  ('W 20 St & 8 Ave', 356),
#  ('W 21 St & 6 Ave', 1057),
#  ('W 22 St & 10 Ave', 409),
#  ('W 22 St & 8 Ave', 420),
#  ('W 24 St & 7 Ave', 572),
#  ('W 25 St & 6 Ave', 442),
#  ('W 26 St & 10 Ave', 357),
#  ('W 26 St & 8 Ave', 488),
#  ('W 27 St & 7 Ave', 592),
#  ('W 29 St & 9 Ave', 275),
#  ('W 31 St & 7 Ave', 842),
#  ('W 33 St & 7 Ave', 828),
#  ('W 34 St & 11 Ave', 117),
#  ('W 37 St & 10 Ave', 328),
#  ('W 37 St & 5 Ave', 287),
#  ('W 38 St & 8 Ave', 589),
#  ('W 39 St & 9 Ave', 573),
#  ('W 4 St & 7 Ave S', 439),
#  ('W 41 St & 8 Ave', 1095),
#  ('W 42 St & 8 Ave', 478),
#  ('W 43 St & 10 Ave', 453),
#  ('W 43 St & 6 Ave', 209),
#  ('W 44 St & 5 Ave', 279),
#  ('W 45 St & 6 Ave', 289),
#  ('W 45 St & 8 Ave', 274),
#  ('W 46 St & 11 Ave', 113),
#  ('W 47 St & 10 Ave', 260),
#  ('W 49 St & 8 Ave', 326),
#  ('W 51 St & 6 Ave', 390),
#  ('W 52 St & 11 Ave', 211),
#  ('W 52 St & 5 Ave', 266),
#  ('W 52 St & 9 Ave', 187),
#  ('W 53 St & 10 Ave', 168),
#  ('W 54 St & 9 Ave', 134),
#  ('W 56 St & 10 Ave', 272),
#  ('W 56 St & 6 Ave', 327),
#  ('W 59 St & 10 Ave', 189),
#  ('W Broadway & Spring St', 333),
#  ('W Houston St & Hudson St', 377),
#  ('Warren St & Church St', 135),
#  ('Washington Ave & Greene Ave', 44),
#  ('Washington Ave & Park Ave', 98),
#  ('Washington Park', 62),
#  ('Washington Pl & 6 Ave', 232),
#  ('Washington Pl & Broadway', 475),
#  ('Washington Square E', 329),
#  ('Washington St & Gansevoort St', 247),
#  ('Water - Whitehall Plaza', 155),
#  ('Watts St & Greenwich St', 151),
#  ('West St & Chambers St', 337),
#  ('West Thames St', 206),
#  ('William St & Pine St', 184),
#  ('Willoughby Ave & Hall St', 66),
#  ('Willoughby Ave & Walworth St', 49),
#  ('Willoughby St & Fleet St', 114),
#  ('Wythe Ave & Metropolitan Ave', 94),
#  ('York St & Jay St', 202)]

# %% [markdown]
# ## Task 2 (0 points)
#
# Below is an example of showing how to use nested jobs and jobs with mappers only using the mapreduce package, thus, no points are included. Our task here is that we would like to filter the output of Task 1 to display only those stations with more than 1000 trips involved, of course, using the MapReduce paradigm.

# %%
def mapper2((station,count)):
    if count>1000:
        yield (station,count)

with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output2 = list(mr.run(mr.run(reader, mapper1, reducer1), mapper2))

output2
# Out:
# [('8 Ave & W 31 St', 1065),
#  ('E 43 St & Vanderbilt Ave', 1003),
#  ('Lafayette St & E 8 St', 1013),
#  ('W 21 St & 6 Ave', 1057),
#  ('W 41 St & 8 Ave', 1095)]

# %% [markdown]
# ## Task 3 (2 points)
#
# We would like to count the number of trips taken between pairs of stations. Trips taken from station A to station B or  from station B to station A are both counted towards the station pair A and B. Please note that the station pair shoud be identified by station names, as a tuple, and in lexical order, i.e. (A,B) instead of (B,A) in this case. The output must be tuples, each consisting of the station pair identification and a count. A portion of the expected output are included below. You are asked to fill in the <b>mapper3</b> and <b>reducer3</b> code block.

# %%
def mapper3(row):
    start1, end1 = row['start_station_name'], row['end_station_name']
    station = tuple(sorted([start1, end1]))
    yield (station, 1)

def reducer3(k2v2):
    station, count = (k2v2)
    return (station, sum(count))

with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output3 = list(mr.run(reader, mapper3, reducer3))

output3
# Out:
# [(('1 Ave & E 15 St', '1 Ave & E 15 St'), 5),
#  (('1 Ave & E 15 St', '1 Ave & E 44 St'), 6),
#  (('1 Ave & E 15 St', '11 Ave & W 27 St'), 1),
#  (('1 Ave & E 15 St', '2 Ave & E 31 St'), 9),
#  (('1 Ave & E 15 St', '5 Ave & E 29 St'), 2),
#  (('1 Ave & E 15 St', '6 Ave & Broome St'), 3),
#  (('1 Ave & E 15 St', '6 Ave & Canal St'), 1),
#  (('1 Ave & E 15 St', '8 Ave & W 31 St'), 5),
#  (('1 Ave & E 15 St', '9 Ave & W 14 St'), 3),
#  (('1 Ave & E 15 St', '9 Ave & W 16 St'), 3),
#  (('1 Ave & E 15 St', '9 Ave & W 18 St'), 1),
#  (('1 Ave & E 15 St', '9 Ave & W 45 St'), 1),
#  (('1 Ave & E 15 St', 'Allen St & E Houston St'), 6),
#  (('1 Ave & E 15 St', 'Allen St & Hester St'), 16),
#  (('1 Ave & E 15 St', 'Allen St & Rivington St'), 9),
#  (('1 Ave & E 15 St', 'Avenue D & E 12 St'), 2),
#  (('1 Ave & E 15 St', 'Avenue D & E 3 St'), 2),
#  (('1 Ave & E 15 St', 'Avenue D & E 8 St'), 1),
#  (('1 Ave & E 15 St', 'Barrow St & Hudson St'), 1),
#  (('1 Ave & E 15 St', 'Bayard St & Baxter St'), 1),
#  (('1 Ave & E 15 St', 'Broadway & Battery Pl'), 1),
#  (('1 Ave & E 15 St', 'Broadway & E 14 St'), 22),
#  (('1 Ave & E 15 St', 'Broadway & E 22 St'), 5),
#  (('1 Ave & E 15 St', 'Broadway & W 24 St'), 5),
#  (('1 Ave & E 15 St', 'Broadway & W 29 St'), 7),
#  (('1 Ave & E 15 St', 'Broadway & W 32 St'), 5),
#  (('1 Ave & E 15 St', 'Broadway & W 36 St'), 4),
#  (('1 Ave & E 15 St', 'Broadway & W 37 St'), 1),
#  (('1 Ave & E 15 St', 'Broadway & W 41 St'), 1),
#  (('1 Ave & E 15 St', 'Broadway & W 49 St'), 1),
#  (('1 Ave & E 15 St', 'Broadway & W 55 St'), 1),
#  (('1 Ave & E 15 St', 'Broadway & W 58 St'), 2),
#  (('1 Ave & E 15 St', 'Carmine St & 6 Ave'), 2),
#  (('1 Ave & E 15 St', 'Catherine St & Monroe St'), 3),
#  (('1 Ave & E 15 St', 'Christopher St & Greenwich St'), 5),
#  (('1 Ave & E 15 St', 'Cleveland Pl & Spring St'), 3),
#  (('1 Ave & E 15 St', 'Cliff St & Fulton St'), 1),
#  (('1 Ave & E 15 St', 'Clinton St & Grand St'), 2),
#  (('1 Ave & E 15 St', 'Columbia St & Rivington St'), 1),
#  (('1 Ave & E 15 St', 'Division St & Bowery'), 1),
#  (('1 Ave & E 15 St', 'E 10 St & 5 Ave'), 2),
#  (('1 Ave & E 15 St', 'E 10 St & Avenue A'), 8),
#  (('1 Ave & E 15 St', 'E 11 St & 1 Ave'), 1),
#  (('1 Ave & E 15 St', 'E 11 St & 2 Ave'), 7),
#  (('1 Ave & E 15 St', 'E 11 St & Broadway'), 4),
#  (('1 Ave & E 15 St', 'E 12 St & 3 Ave'), 10),
#  (('1 Ave & E 15 St', 'E 13 St & Avenue A'), 2),
#  (('1 Ave & E 15 St', 'E 14 St & Avenue B'), 11),
#  (('1 Ave & E 15 St', 'E 15 St & 3 Ave'), 16),
#  (('1 Ave & E 15 St', 'E 16 St & 5 Ave'), 4),
#  (('1 Ave & E 15 St', 'E 16 St & Irving Pl'), 3),
#  (('1 Ave & E 15 St', 'E 17 St & Broadway'), 34),
#  (('1 Ave & E 15 St', 'E 19 St & 3 Ave'), 4),
#  (('1 Ave & E 15 St', 'E 2 St & 2 Ave'), 6),
#  (('1 Ave & E 15 St', 'E 2 St & Avenue B'), 3),
#  (('1 Ave & E 15 St', 'E 2 St & Avenue C'), 3),
#  (('1 Ave & E 15 St', 'E 20 St & 2 Ave'), 10),
#  (('1 Ave & E 15 St', 'E 20 St & FDR Drive'), 33),
#  (('1 Ave & E 15 St', 'E 20 St & Park Ave'), 5),
#  (('1 Ave & E 15 St', 'E 23 St & 1 Ave'), 14),
#  (('1 Ave & E 15 St', 'E 24 St & Park Ave S'), 9),
#  (('1 Ave & E 15 St', 'E 25 St & 1 Ave'), 15),
#  (('1 Ave & E 15 St', 'E 25 St & 2 Ave'), 13),
#  (('1 Ave & E 15 St', 'E 27 St & 1 Ave'), 20),
#  (('1 Ave & E 15 St', 'E 3 St & 1 Ave'), 10),
#  (('1 Ave & E 15 St', 'E 30 St & Park Ave S'), 3),
#  (('1 Ave & E 15 St', 'E 31 St & 3 Ave'), 7),
#  (('1 Ave & E 15 St', 'E 32 St & Park Ave'), 4),
#  (('1 Ave & E 15 St', 'E 33 St & 2 Ave'), 15),
#  (('1 Ave & E 15 St', 'E 33 St & 5 Ave'), 3),
#  (('1 Ave & E 15 St', 'E 37 St & Lexington Ave'), 3),
#  (('1 Ave & E 15 St', 'E 39 St & 2 Ave'), 13),
#  (('1 Ave & E 15 St', 'E 39 St & 3 Ave'), 3),
#  (('1 Ave & E 15 St', 'E 4 St & 2 Ave'), 5),
#  (('1 Ave & E 15 St', 'E 40 St & 5 Ave'), 2),
#  (('1 Ave & E 15 St', 'E 43 St & Vanderbilt Ave'), 1),
#  (('1 Ave & E 15 St', 'E 45 St & 3 Ave'), 1),
#  (('1 Ave & E 15 St', 'E 47 St & 1 Ave'), 1),
#  (('1 Ave & E 15 St', 'E 47 St & 2 Ave'), 1),
#  (('1 Ave & E 15 St', 'E 5 St & Avenue C'), 8),
#  (('1 Ave & E 15 St', 'E 51 St & 1 Ave'), 1),
#  (('1 Ave & E 15 St', 'E 51 St & Lexington Ave'), 2),
#  (('1 Ave & E 15 St', 'E 53 St & Lexington Ave'), 1),
#  (('1 Ave & E 15 St', 'E 56 St & 3 Ave'), 1),
#  (('1 Ave & E 15 St', 'E 59 St & Sutton Pl'), 4),
#  (('1 Ave & E 15 St', 'E 6 St & Avenue B'), 9),
#  (('1 Ave & E 15 St', 'E 6 St & Avenue D'), 5),
#  (('1 Ave & E 15 St', 'E 7 St & Avenue A'), 11),
#  (('1 Ave & E 15 St', 'E 9 St & Avenue C'), 13),
#  (('1 Ave & E 15 St', 'Elizabeth St & Hester St'), 2),
#  (('1 Ave & E 15 St', 'FDR Drive & E 35 St'), 1),
#  (('1 Ave & E 15 St', 'Forsyth St & Broome St'), 7),
#  (('1 Ave & E 15 St', 'Forsyth St & Canal St'), 2),
#  (('1 Ave & E 15 St', 'Front St & Maiden Ln'), 2),
#  (('1 Ave & E 15 St', 'Grand Army Plaza & Central Park S'), 3),
#  (('1 Ave & E 15 St', 'Great Jones St'), 9),
#  (('1 Ave & E 15 St', 'Greenwich Ave & 8 Ave'), 2),
#  (('1 Ave & E 15 St', 'Howard St & Centre St'), 1),
#  (('1 Ave & E 15 St', 'Hudson St & Reade St'), 1),
#  (('1 Ave & E 15 St', 'LaGuardia Pl & W 3 St'), 6),
#  (('1 Ave & E 15 St', 'Lafayette St & E 8 St'), 18),
#  (('1 Ave & E 15 St', 'Lafayette St & Jersey St'), 3),
#  (('1 Ave & E 15 St', 'Leonard St & Church St'), 1),
#  (('1 Ave & E 15 St', 'Lexington Ave & E 24 St'), 12),
#  (('1 Ave & E 15 St', 'Liberty St & Broadway'), 1),
#  (('1 Ave & E 15 St', 'Little West St & 1 Pl'), 4),
#  (('1 Ave & E 15 St', 'MacDougal St & Prince St'), 3),
#  (('1 Ave & E 15 St', 'MacDougal St & Washington Sq'), 2),
#  (('1 Ave & E 15 St', 'Maiden Ln & Pearl St'), 1),
#  (('1 Ave & E 15 St', 'Market St & Cherry St'), 1),
#  (('1 Ave & E 15 St', 'Mercer St & Bleecker St'), 2),
#  (('1 Ave & E 15 St', 'Mercer St & Spring St'), 1),
#  (('1 Ave & E 15 St', 'Mott St & Prince St'), 4),
#  (('1 Ave & E 15 St', 'Norfolk St & Broome St'), 2),
#  (('1 Ave & E 15 St', 'Peck Slip & Front St'), 4),
#  (('1 Ave & E 15 St', 'Pershing Square North'), 5),
#  (('1 Ave & E 15 St', 'Pershing Square South'), 2),
#  (('1 Ave & E 15 St', 'Pike St & E Broadway'), 13),
#  (('1 Ave & E 15 St', 'Pitt St & Stanton St'), 1),
#  (('1 Ave & E 15 St', 'Shevchenko Pl & E 7 St'), 6),
#  (('1 Ave & E 15 St', 'Spruce St & Nassau St'), 2),
#  (('1 Ave & E 15 St', 'St James Pl & Oliver St'), 1),
#  (('1 Ave & E 15 St', 'St Marks Pl & 1 Ave'), 2),
#  (('1 Ave & E 15 St', 'St Marks Pl & 2 Ave'), 14),
#  (('1 Ave & E 15 St', 'Stanton St & Chrystie St'), 1),
#  (('1 Ave & E 15 St', 'Stanton St & Mangin St'), 7),
#  (('1 Ave & E 15 St', 'Suffolk St & Stanton St'), 3),
#  (('1 Ave & E 15 St', 'Sullivan St & Washington Sq'), 3),
#  (('1 Ave & E 15 St', 'University Pl & E 14 St'), 8),
#  (('1 Ave & E 15 St', 'W 11 St & 6 Ave'), 2),
#  (('1 Ave & E 15 St', 'W 13 St & 6 Ave'), 10),
#  (('1 Ave & E 15 St', 'W 13 St & 7 Ave'), 5),
#  (('1 Ave & E 15 St', 'W 15 St & 7 Ave'), 3),
#  (('1 Ave & E 15 St', 'W 16 St & The High Line'), 2),
#  (('1 Ave & E 15 St', 'W 17 St & 8 Ave'), 5),
#  (('1 Ave & E 15 St', 'W 18 St & 6 Ave'), 8),
#  (('1 Ave & E 15 St', 'W 20 St & 11 Ave'), 5),
#  (('1 Ave & E 15 St', 'W 20 St & 7 Ave'), 4),
#  (('1 Ave & E 15 St', 'W 21 St & 6 Ave'), 3),
#  (('1 Ave & E 15 St', 'W 22 St & 10 Ave'), 4),
#  (('1 Ave & E 15 St', 'W 22 St & 8 Ave'), 3),
#  (('1 Ave & E 15 St', 'W 24 St & 7 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 25 St & 6 Ave'), 4),
#  (('1 Ave & E 15 St', 'W 27 St & 7 Ave'), 2),
#  (('1 Ave & E 15 St', 'W 31 St & 7 Ave'), 9),
#  (('1 Ave & E 15 St', 'W 33 St & 7 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 37 St & 5 Ave'), 4),
#  (('1 Ave & E 15 St', 'W 4 St & 7 Ave S'), 3),
#  (('1 Ave & E 15 St', 'W 41 St & 8 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 43 St & 10 Ave'), 3),
#  (('1 Ave & E 15 St', 'W 44 St & 5 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 52 St & 11 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 52 St & 5 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 52 St & 9 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 54 St & 9 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 56 St & 6 Ave'), 1),
#  (('1 Ave & E 15 St', 'W 59 St & 10 Ave'), 5),
#  (('1 Ave & E 15 St', 'W Broadway & Spring St'), 1),
#  (('1 Ave & E 15 St', 'W Houston St & Hudson St'), 1),
#  (('1 Ave & E 15 St', 'Warren St & Church St'), 4),
#  (('1 Ave & E 15 St', 'Washington Pl & Broadway'), 10),
#  (('1 Ave & E 15 St', 'Washington Square E'), 2),
#  (('1 Ave & E 15 St', 'Wythe Ave & Metropolitan Ave'), 1),
#  (('1 Ave & E 44 St', '1 Ave & E 44 St'), 1),
#  (('1 Ave & E 44 St', '10 Ave & W 28 St'), 3),
#  (('1 Ave & E 44 St', '2 Ave & E 31 St'), 2),
#  (('1 Ave & E 44 St', '2 Ave & E 58 St'), 4),
#  (('1 Ave & E 44 St', '5 Ave & E 29 St'), 3),
#  (('1 Ave & E 44 St', '6 Ave & W 33 St'), 4),
#  (('1 Ave & E 44 St', '8 Ave & W 31 St'), 4),
#  (('1 Ave & E 44 St', '8 Ave & W 33 St'), 1),
#  (('1 Ave & E 44 St', 'Allen St & Hester St'), 2),
#  (('1 Ave & E 44 St', 'Bialystoker Pl & Delancey St'), 2),
#  (('1 Ave & E 44 St', 'Broadway & E 14 St'), 1),
#  (('1 Ave & E 44 St', 'Broadway & E 22 St'), 1),
#  (('1 Ave & E 44 St', 'Broadway & W 24 St'), 2),
#  (('1 Ave & E 44 St', 'Broadway & W 32 St'), 1),
#  (('1 Ave & E 44 St', 'Broadway & W 41 St'), 2),
#  (('1 Ave & E 44 St', 'Broadway & W 49 St'), 1),
#  (('1 Ave & E 44 St', 'Broadway & W 60 St'), 1),
#  (('1 Ave & E 44 St', 'Canal St & Rutgers St'), 1),
#  (('1 Ave & E 44 St', 'Cherry St'), 1),
#  (('1 Ave & E 44 St', 'E 11 St & 2 Ave'), 1),
#  (('1 Ave & E 44 St', 'E 15 St & 3 Ave'), 1),
#  (('1 Ave & E 44 St', 'E 17 St & Broadway'), 1),
#  (('1 Ave & E 44 St', 'E 2 St & Avenue C'), 2),
#  (('1 Ave & E 44 St', 'E 20 St & 2 Ave'), 1),
#  (('1 Ave & E 44 St', 'E 20 St & FDR Drive'), 1),
#  (('1 Ave & E 44 St', 'E 23 St & 1 Ave'), 3),
#  (('1 Ave & E 44 St', 'E 25 St & 1 Ave'), 4),
#  (('1 Ave & E 44 St', 'E 27 St & 1 Ave'), 4),
#  (('1 Ave & E 44 St', 'E 3 St & 1 Ave'), 1),
#  (('1 Ave & E 44 St', 'E 33 St & 2 Ave'), 2),
#  (('1 Ave & E 44 St', 'E 33 St & 5 Ave'), 2),
#  (('1 Ave & E 44 St', 'E 39 St & 3 Ave'), 1),
#  (('1 Ave & E 44 St', 'E 4 St & 2 Ave'), 1),
#  (('1 Ave & E 44 St', 'E 40 St & 5 Ave'), 2),
#  (('1 Ave & E 44 St', 'E 43 St & 2 Ave'), 1),
#  (('1 Ave & E 44 St', 'E 43 St & Vanderbilt Ave'), 1),
#  (('1 Ave & E 44 St', 'E 45 St & 3 Ave'), 3),
#  (('1 Ave & E 44 St', 'E 47 St & 1 Ave'), 4),
#  (('1 Ave & E 44 St', 'E 47 St & 2 Ave'), 4),
#  (('1 Ave & E 44 St', 'E 47 St & Park Ave'), 1),
#  (('1 Ave & E 44 St', 'E 48 St & Madison Ave'), 1),
#  (('1 Ave & E 44 St', 'E 5 St & Avenue C'), 11),
#  (('1 Ave & E 44 St', 'E 51 St & 1 Ave'), 10),
#  (('1 Ave & E 44 St', 'E 52 St & 2 Ave'), 6),
#  (('1 Ave & E 44 St', 'E 53 St & Lexington Ave'), 3),
#  (('1 Ave & E 44 St', 'E 53 St & Madison Ave'), 3),
#  (('1 Ave & E 44 St', 'E 55 St & 2 Ave'), 7),
#  (('1 Ave & E 44 St', 'E 55 St & Lexington Ave'), 3),
#  (('1 Ave & E 44 St', 'E 56 St & Madison Ave'), 2),
#  (('1 Ave & E 44 St', 'E 58 St & 3 Ave'), 6),
#  (('1 Ave & E 44 St', 'E 59 St & Sutton Pl'), 3),
#  (('1 Ave & E 44 St', 'E 6 St & Avenue B'), 1),
#  (('1 Ave & E 44 St', 'FDR Drive & E 35 St'), 1),
#  (('1 Ave & E 44 St', 'Forsyth St & Broome St'), 1),
#  (('1 Ave & E 44 St', 'Grand Army Plaza & Central Park S'), 1),
#  (('1 Ave & E 44 St', 'Kent Ave & S 11 St'), 1),
#  (('1 Ave & E 44 St', 'Lafayette St & Jersey St'), 1),
#  (('1 Ave & E 44 St', 'MacDougal St & Washington Sq'), 1),
#  (('1 Ave & E 44 St', 'Myrtle Ave & St Edwards St'), 1),
#  (('1 Ave & E 44 St', 'Pershing Square North'), 6),
#  (('1 Ave & E 44 St', 'Pershing Square South'), 4),
#  (('1 Ave & E 44 St', 'Shevchenko Pl & E 7 St'), 1),
#  (('1 Ave & E 44 St', 'Stanton St & Chrystie St'), 4),
#  (('1 Ave & E 44 St', 'State St & Smith St'), 1),
#  (('1 Ave & E 44 St', 'Sullivan St & Washington Sq'), 1),
#  (('1 Ave & E 44 St', 'W 20 St & 7 Ave'), 3),
#  (('1 Ave & E 44 St', 'W 24 St & 7 Ave'), 2),
#  (('1 Ave & E 44 St', 'W 26 St & 10 Ave'), 1),
#  (('1 Ave & E 44 St', 'W 29 St & 9 Ave'), 1),
#  (('1 Ave & E 44 St', 'W 31 St & 7 Ave'), 1),
#  (('1 Ave & E 44 St', 'W 33 St & 7 Ave'), 20),
#  (('1 Ave & E 44 St', 'W 37 St & 5 Ave'), 5),
#  (('1 Ave & E 44 St', 'W 39 St & 9 Ave'), 5),
#  (('1 Ave & E 44 St', 'W 41 St & 8 Ave'), 9),
#  (('1 Ave & E 44 St', 'W 42 St & 8 Ave'), 4),
#  (('1 Ave & E 44 St', 'W 44 St & 5 Ave'), 2),
#  (('1 Ave & E 44 St', 'W 45 St & 8 Ave'), 1),
#  (('10 Ave & W 28 St', '10 Ave & W 28 St'), 4),
#  (('10 Ave & W 28 St', '11 Ave & W 27 St'), 2),
#  (('10 Ave & W 28 St', '11 Ave & W 41 St'), 1),
#  (('10 Ave & W 28 St', '11 Ave & W 59 St'), 1),
#  (('10 Ave & W 28 St', '2 Ave & E 58 St'), 1),
#  (('10 Ave & W 28 St', '5 Ave & E 29 St'), 3),
#  (('10 Ave & W 28 St', '6 Ave & Broome St'), 2),
#  (('10 Ave & W 28 St', '6 Ave & Canal St'), 1),
#  (('10 Ave & W 28 St', '6 Ave & W 33 St'), 6),
#  (('10 Ave & W 28 St', '8 Ave & W 31 St'), 37),
#  (('10 Ave & W 28 St', '8 Ave & W 33 St'), 11),
#  (('10 Ave & W 28 St', '9 Ave & W 14 St'), 2),
#  (('10 Ave & W 28 St', '9 Ave & W 16 St'), 3),
#  (('10 Ave & W 28 St', '9 Ave & W 18 St'), 5),
#  (('10 Ave & W 28 St', '9 Ave & W 22 St'), 6),
#  (('10 Ave & W 28 St', '9 Ave & W 45 St'), 5),
#  (('10 Ave & W 28 St', 'Bank St & Hudson St'), 3),
#  (('10 Ave & W 28 St', 'Broadway & E 14 St'), 3),
#  (('10 Ave & W 28 St', 'Broadway & E 22 St'), 8),
#  (('10 Ave & W 28 St', 'Broadway & W 24 St'), 2),
#  (('10 Ave & W 28 St', 'Broadway & W 29 St'), 2),
#  (('10 Ave & W 28 St', 'Broadway & W 32 St'), 2),
#  (('10 Ave & W 28 St', 'Broadway & W 36 St'), 3),
#  (('10 Ave & W 28 St', 'Broadway & W 39 St'), 3),
#  (('10 Ave & W 28 St', 'Broadway & W 41 St'), 2),
#  (('10 Ave & W 28 St', 'Broadway & W 51 St'), 1),
#  (('10 Ave & W 28 St', 'Broadway & W 55 St'), 1),
#  (('10 Ave & W 28 St', 'Broadway & W 60 St'), 2),
#  (('10 Ave & W 28 St', 'Carmine St & 6 Ave'), 2),
#  (('10 Ave & W 28 St', 'Christopher St & Greenwich St'), 3),
#  (('10 Ave & W 28 St', 'E 10 St & 5 Ave'), 4),
#  (('10 Ave & W 28 St', 'E 11 St & 2 Ave'), 1),
#  (('10 Ave & W 28 St', 'E 12 St & 3 Ave'), 2),
#  (('10 Ave & W 28 St', 'E 13 St & Avenue A'), 2),
#  (('10 Ave & W 28 St', 'E 16 St & 5 Ave'), 1),
#  (('10 Ave & W 28 St', 'E 17 St & Broadway'), 10),
#  (('10 Ave & W 28 St', 'E 20 St & 2 Ave'), 1),
#  (('10 Ave & W 28 St', 'E 20 St & Park Ave'), 1),
#  (('10 Ave & W 28 St', 'E 24 St & Park Ave S'), 5),
#  (('10 Ave & W 28 St', 'E 30 St & Park Ave S'), 2),
#  (('10 Ave & W 28 St', 'E 32 St & Park Ave'), 6),
#  (('10 Ave & W 28 St', 'E 33 St & 5 Ave'), 2),
#  (('10 Ave & W 28 St', 'E 37 St & Lexington Ave'), 4),
#  (('10 Ave & W 28 St', 'E 39 St & 2 Ave'), 1),
#  (('10 Ave & W 28 St', 'E 39 St & 3 Ave'), 2),
#  (('10 Ave & W 28 St', 'E 40 St & 5 Ave'), 5),
#  (('10 Ave & W 28 St', 'E 47 St & 1 Ave'), 1),
#  (('10 Ave & W 28 St', 'E 47 St & Park Ave'), 1),
#  (('10 Ave & W 28 St', 'E 48 St & Madison Ave'), 5),
#  (('10 Ave & W 28 St', 'E 59 St & Sutton Pl'), 1),
#  (('10 Ave & W 28 St', 'FDR Drive & E 35 St'), 1),
#  (('10 Ave & W 28 St', 'Forsyth St & Broome St'), 1),
#  (('10 Ave & W 28 St', 'Forsyth St & Canal St'), 1),
#  (('10 Ave & W 28 St', 'Franklin St & W Broadway'), 1),
#  (('10 Ave & W 28 St', 'Greenwich Ave & 8 Ave'), 9),
#  (('10 Ave & W 28 St', 'Lafayette St & E 8 St'), 5),
#  (('10 Ave & W 28 St', 'MacDougal St & Washington Sq'), 1),
#  (('10 Ave & W 28 St', 'Mott St & Prince St'), 1),
#  (('10 Ave & W 28 St', 'Murray St & West St'), 1),
#  (('10 Ave & W 28 St', 'Sullivan St & Washington Sq'), 1),
#  (('10 Ave & W 28 St', 'University Pl & E 14 St'), 2),
#  (('10 Ave & W 28 St', 'W 13 St & 6 Ave'), 5),
#  (('10 Ave & W 28 St', 'W 14 St & The High Line'), 1),
#  (('10 Ave & W 28 St', 'W 15 St & 7 Ave'), 7),
#  (('10 Ave & W 28 St', 'W 16 St & The High Line'), 11),
#  (('10 Ave & W 28 St', 'W 17 St & 8 Ave'), 6),
#  (('10 Ave & W 28 St', 'W 18 St & 6 Ave'), 4),
#  (('10 Ave & W 28 St', 'W 20 St & 11 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 20 St & 7 Ave'), 11),
#  (('10 Ave & W 28 St', 'W 20 St & 8 Ave'), 5),
#  (('10 Ave & W 28 St', 'W 21 St & 6 Ave'), 12),
#  (('10 Ave & W 28 St', 'W 22 St & 10 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 22 St & 8 Ave'), 11),
#  (('10 Ave & W 28 St', 'W 24 St & 7 Ave'), 22),
#  (('10 Ave & W 28 St', 'W 25 St & 6 Ave'), 4),
#  (('10 Ave & W 28 St', 'W 26 St & 10 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 26 St & 8 Ave'), 34),
#  (('10 Ave & W 28 St', 'W 27 St & 7 Ave'), 26),
#  (('10 Ave & W 28 St', 'W 31 St & 7 Ave'), 4),
#  (('10 Ave & W 28 St', 'W 33 St & 7 Ave'), 5),
#  (('10 Ave & W 28 St', 'W 38 St & 8 Ave'), 2),
#  (('10 Ave & W 28 St', 'W 39 St & 9 Ave'), 3),
#  (('10 Ave & W 28 St', 'W 41 St & 8 Ave'), 2),
#  (('10 Ave & W 28 St', 'W 42 St & 8 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 43 St & 10 Ave'), 3),
#  (('10 Ave & W 28 St', 'W 43 St & 6 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 45 St & 8 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 47 St & 10 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 49 St & 8 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 52 St & 5 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 52 St & 9 Ave'), 2),
#  (('10 Ave & W 28 St', 'W 53 St & 10 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 56 St & 10 Ave'), 2),
#  (('10 Ave & W 28 St', 'W 56 St & 6 Ave'), 1),
#  (('10 Ave & W 28 St', 'W 59 St & 10 Ave'), 1),
#  (('10 Ave & W 28 St', 'W Houston St & Hudson St'), 6),
#  (('10 Ave & W 28 St', 'Washington Pl & 6 Ave'), 4),
#  (('10 Ave & W 28 St', 'Washington St & Gansevoort St'), 1),
#  (('10 Ave & W 28 St', 'Water - Whitehall Plaza'), 2),
#  (('11 Ave & W 27 St', '11 Ave & W 27 St'), 2),
#  (('11 Ave & W 27 St', '11 Ave & W 41 St'), 4),
#  (('11 Ave & W 27 St', '11 Ave & W 59 St'), 4),
#  (('11 Ave & W 27 St', '12 Ave & W 40 St'), 2),
#  (('11 Ave & W 27 St', '2 Ave & E 31 St'), 1),
#  (('11 Ave & W 27 St', '5 Ave & E 29 St'), 1),
#  (('11 Ave & W 27 St', '6 Ave & Canal St'), 2),
#  (('11 Ave & W 27 St', '6 Ave & W 33 St'), 2),
#  (('11 Ave & W 27 St', '8 Ave & W 31 St'), 42),
#  (('11 Ave & W 27 St', '8 Ave & W 33 St'), 1),
#  (('11 Ave & W 27 St', '9 Ave & W 14 St'), 2),
#  (('11 Ave & W 27 St', '9 Ave & W 16 St'), 6),
#  (('11 Ave & W 27 St', '9 Ave & W 18 St'), 3),
#  (('11 Ave & W 27 St', '9 Ave & W 22 St'), 6),
#  (('11 Ave & W 27 St', '9 Ave & W 45 St'), 1),
#  (('11 Ave & W 27 St', 'Allen St & E Houston St'), 3),
#  (('11 Ave & W 27 St', 'Bank St & Hudson St'), 1),
#  (('11 Ave & W 27 St', 'Barrow St & Hudson St'), 1),
#  (('11 Ave & W 27 St', 'Broadway & W 24 St'), 1),
#  (('11 Ave & W 27 St', 'Broadway & W 29 St'), 4),
#  (('11 Ave & W 27 St', 'Broadway & W 32 St'), 5),
#  (('11 Ave & W 27 St', 'Broadway & W 37 St'), 1),
#  (('11 Ave & W 27 St', 'Broadway & W 55 St'), 1),
#  (('11 Ave & W 27 St', 'Broadway & W 58 St'), 1),
#  (('11 Ave & W 27 St', 'Broadway & W 60 St'), 3),
#  (('11 Ave & W 27 St', 'Carmine St & 6 Ave'), 1),
#  (('11 Ave & W 27 St', 'Christopher St & Greenwich St'), 2),
#  (('11 Ave & W 27 St', 'Duane St & Greenwich St'), 2),
#  (('11 Ave & W 27 St', 'E 10 St & Avenue A'), 3),
#  (('11 Ave & W 27 St', 'E 11 St & 1 Ave'), 1),
#  (('11 Ave & W 27 St', 'E 13 St & Avenue A'), 1),
#  (('11 Ave & W 27 St', 'E 16 St & 5 Ave'), 1),
#  (('11 Ave & W 27 St', 'E 17 St & Broadway'), 3),
#  (('11 Ave & W 27 St', 'E 20 St & Park Ave'), 2),
#  (('11 Ave & W 27 St', 'E 25 St & 2 Ave'), 6),
#  (('11 Ave & W 27 St', 'E 30 St & Park Ave S'), 1),
#  (('11 Ave & W 27 St', 'E 32 St & Park Ave'), 6),
#  (('11 Ave & W 27 St', 'E 33 St & 5 Ave'), 1),
#  (('11 Ave & W 27 St', 'E 37 St & Lexington Ave'), 1),
#  (('11 Ave & W 27 St', 'E 39 St & 2 Ave'), 2),
#  (('11 Ave & W 27 St', 'E 39 St & 3 Ave'), 1),
#  (('11 Ave & W 27 St', 'E 40 St & 5 Ave'), 1),
#  (('11 Ave & W 27 St', 'E 43 St & Vanderbilt Ave'), 1),
#  (('11 Ave & W 27 St', 'E 47 St & 2 Ave'), 1),
#  (('11 Ave & W 27 St', 'E 6 St & Avenue B'), 1),
#  (('11 Ave & W 27 St', 'Great Jones St'), 1),
#  (('11 Ave & W 27 St', 'Greenwich Ave & 8 Ave'), 2),
#  (('11 Ave & W 27 St', 'Greenwich St & N Moore St'), 1),
#  (('11 Ave & W 27 St', 'Greenwich St & Warren St'), 1),
#  (('11 Ave & W 27 St', 'John St & William St'), 1),
#  (('11 Ave & W 27 St', 'Lafayette St & E 8 St'), 3),
#  (('11 Ave & W 27 St', 'Lafayette St & Jersey St'), 1),
#  (('11 Ave & W 27 St', 'Little West St & 1 Pl'), 1),
#  (('11 Ave & W 27 St', 'MacDougal St & Prince St'), 1),
#  (('11 Ave & W 27 St', 'MacDougal St & Washington Sq'), 1),
#  (('11 Ave & W 27 St', 'Perry St & Bleecker St'), 1),
#  (('11 Ave & W 27 St', 'Pershing Square North'), 2),
#  (('11 Ave & W 27 St', 'Pershing Square South'), 3),
#  (('11 Ave & W 27 St', 'Shevchenko Pl & E 7 St'), 1),
#  (('11 Ave & W 27 St', 'St Marks Pl & 2 Ave'), 2),
#  (('11 Ave & W 27 St', 'Vesey Pl & River Terrace'), 1),
#  (('11 Ave & W 27 St', 'W 16 St & The High Line'), 7),
#  (('11 Ave & W 27 St', 'W 17 St & 8 Ave'), 9),
#  (('11 Ave & W 27 St', 'W 18 St & 6 Ave'), 5),
#  (('11 Ave & W 27 St', 'W 20 St & 11 Ave'), 3),
#  (('11 Ave & W 27 St', 'W 20 St & 7 Ave'), 3),
#  (('11 Ave & W 27 St', 'W 20 St & 8 Ave'), 4),
#  (('11 Ave & W 27 St', 'W 21 St & 6 Ave'), 5),
#  (('11 Ave & W 27 St', 'W 22 St & 10 Ave'), 1),
#  (('11 Ave & W 27 St', 'W 22 St & 8 Ave'), 2),
#  (('11 Ave & W 27 St', 'W 24 St & 7 Ave'), 5),
#  (('11 Ave & W 27 St', 'W 25 St & 6 Ave'), 12),
#  (('11 Ave & W 27 St', 'W 26 St & 10 Ave'), 1),
#  (('11 Ave & W 27 St', 'W 26 St & 8 Ave'), 48),
#  (('11 Ave & W 27 St', 'W 27 St & 7 Ave'), 19),
#  (('11 Ave & W 27 St', 'W 29 St & 9 Ave'), 6),
#  (('11 Ave & W 27 St', 'W 33 St & 7 Ave'), 2),
#  (('11 Ave & W 27 St', 'W 37 St & 10 Ave'), 3),
#  (('11 Ave & W 27 St', 'W 38 St & 8 Ave'), 1),
#  (('11 Ave & W 27 St', 'W 39 St & 9 Ave'), 26),
#  (('11 Ave & W 27 St', 'W 4 St & 7 Ave S'), 3),
#  (('11 Ave & W 27 St', 'W 41 St & 8 Ave'), 3),
#  (('11 Ave & W 27 St', 'W 42 St & 8 Ave'), 3),
#  (('11 Ave & W 27 St', 'W 43 St & 10 Ave'), 1),
#  (('11 Ave & W 27 St', 'W 45 St & 6 Ave'), 1),
#  (('11 Ave & W 27 St', 'W 46 St & 11 Ave'), 2),
#  (('11 Ave & W 27 St', 'W 47 St & 10 Ave'), 1),
#  (('11 Ave & W 27 St', 'W 52 St & 11 Ave'), 4),
#  (('11 Ave & W 27 St', 'W 56 St & 6 Ave'), 1),
#  (('11 Ave & W 27 St', 'W 59 St & 10 Ave'), 1),
#  (('11 Ave & W 27 St', 'W Houston St & Hudson St'), 1),
#  (('11 Ave & W 27 St', 'Washington Pl & 6 Ave'), 1),
#  (('11 Ave & W 27 St', 'Washington Pl & Broadway'), 1),
#  (('11 Ave & W 27 St', 'Washington St & Gansevoort St'), 1),
#  (('11 Ave & W 27 St', 'West St & Chambers St'), 2),
#  (('11 Ave & W 41 St', '11 Ave & W 41 St'), 3),
#  (('11 Ave & W 41 St', '11 Ave & W 59 St'), 5),
#  (('11 Ave & W 41 St', '12 Ave & W 40 St'), 3),
#  (('11 Ave & W 41 St', '5 Ave & E 29 St'), 9),
#  (('11 Ave & W 41 St', '6 Ave & Canal St'), 1),
#  (('11 Ave & W 41 St', '6 Ave & W 33 St'), 6),
#  (('11 Ave & W 41 St', '8 Ave & W 31 St'), 9),
#  (('11 Ave & W 41 St', '8 Ave & W 33 St'), 53),
#  (('11 Ave & W 41 St', '8 Ave & W 52 St'), 4),
#  (('11 Ave & W 41 St', '9 Ave & W 14 St'), 1),
#  (('11 Ave & W 41 St', '9 Ave & W 16 St'), 1),
#  (('11 Ave & W 41 St', '9 Ave & W 22 St'), 5),
#  (('11 Ave & W 41 St', '9 Ave & W 45 St'), 5),
#  (('11 Ave & W 41 St', 'Bank St & Washington St'), 3),
#  (('11 Ave & W 41 St', 'Barrow St & Hudson St'), 1),
#  (('11 Ave & W 41 St', 'Broadway & E 14 St'), 1),
#  (('11 Ave & W 41 St', 'Broadway & E 22 St'), 3),
#  (('11 Ave & W 41 St', 'Broadway & W 29 St'), 4),
#  (('11 Ave & W 41 St', 'Broadway & W 32 St'), 3),
#  (('11 Ave & W 41 St', 'Broadway & W 36 St'), 1),
#  (('11 Ave & W 41 St', 'Broadway & W 37 St'), 6),
#  (('11 Ave & W 41 St', 'Broadway & W 39 St'), 4),
#  (('11 Ave & W 41 St', 'Broadway & W 41 St'), 21),
#  (('11 Ave & W 41 St', 'Broadway & W 49 St'), 13),
#  (('11 Ave & W 41 St', 'Broadway & W 51 St'), 3),
#  (('11 Ave & W 41 St', 'Broadway & W 53 St'), 5),
#  (('11 Ave & W 41 St', 'Broadway & W 58 St'), 3),
#  (('11 Ave & W 41 St', 'Broadway & W 60 St'), 7),
#  (('11 Ave & W 41 St', 'Catherine St & Monroe St'), 1),
#  (('11 Ave & W 41 St', 'Christopher St & Greenwich St'), 1),
#  (('11 Ave & W 41 St', 'Division St & Bowery'), 1),
#  (('11 Ave & W 41 St', 'E 11 St & 2 Ave'), 1),
#  (('11 Ave & W 41 St', 'E 15 St & 3 Ave'), 1),
#  (('11 Ave & W 41 St', 'E 16 St & Irving Pl'), 1),
#  (('11 Ave & W 41 St', 'E 24 St & Park Ave S'), 1),
#  (('11 Ave & W 41 St', 'E 25 St & 2 Ave'), 1),
#  (('11 Ave & W 41 St', 'E 30 St & Park Ave S'), 2),
#  (('11 Ave & W 41 St', 'E 39 St & 3 Ave'), 4),
#  (('11 Ave & W 41 St', 'E 40 St & 5 Ave'), 4),
#  (('11 Ave & W 41 St', 'E 43 St & Vanderbilt Ave'), 10),
#  (('11 Ave & W 41 St', 'E 45 St & 3 Ave'), 2),
#  (('11 Ave & W 41 St', 'E 47 St & Park Ave'), 1),
#  (('11 Ave & W 41 St', 'E 48 St & 3 Ave'), 1),
#  (('11 Ave & W 41 St', 'E 48 St & Madison Ave'), 1),
#  (('11 Ave & W 41 St', 'E 51 St & Lexington Ave'), 2),
#  (('11 Ave & W 41 St', 'E 55 St & Lexington Ave'), 1),
#  (('11 Ave & W 41 St', 'E 56 St & Madison Ave'), 2),
#  (('11 Ave & W 41 St', 'E 58 St & 3 Ave'), 1),
#  (('11 Ave & W 41 St', 'Grand St & Greene St'), 1),
#  (('11 Ave & W 41 St', 'Greenwich Ave & 8 Ave'), 3),
#  (('11 Ave & W 41 St', 'Greenwich St & N Moore St'), 1),
#  (('11 Ave & W 41 St', 'Harrison St & Hudson St'), 1),
#  (('11 Ave & W 41 St', 'Lafayette St & Jersey St'), 1),
#  (('11 Ave & W 41 St', 'Laight St & Hudson St'), 1),
#  (('11 Ave & W 41 St', 'Lexington Ave & E 24 St'), 7),
#  (('11 Ave & W 41 St', 'Little West St & 1 Pl'), 1),
#  (('11 Ave & W 41 St', 'MacDougal St & Prince St'), 1),
#  (('11 Ave & W 41 St', 'Murray St & West St'), 1),
#  (('11 Ave & W 41 St', 'Perry St & Bleecker St'), 5),
#  (('11 Ave & W 41 St', 'Pershing Square North'), 2),
#  (('11 Ave & W 41 St', 'Pershing Square South'), 2),
#  (('11 Ave & W 41 St', 'Reade St & Broadway'), 1),
#  (('11 Ave & W 41 St', 'Rivington St & Chrystie St'), 1),
#  (('11 Ave & W 41 St', 'South End Ave & Liberty St'), 2),
#  (('11 Ave & W 41 St', 'St Marks Pl & 1 Ave'), 1),
#  (('11 Ave & W 41 St', 'Suffolk St & Stanton St'), 2),
#  (('11 Ave & W 41 St', 'University Pl & E 14 St'), 1),
#  (('11 Ave & W 41 St', 'Vesey Pl & River Terrace'), 4),
#  (('11 Ave & W 41 St', 'W 14 St & The High Line'), 2),
#  (('11 Ave & W 41 St', 'W 16 St & The High Line'), 12),
#  (('11 Ave & W 41 St', 'W 17 St & 8 Ave'), 1),
#  (('11 Ave & W 41 St', 'W 18 St & 6 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 20 St & 11 Ave'), 13),
#  (('11 Ave & W 41 St', 'W 20 St & 7 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 21 St & 6 Ave'), 11),
#  (('11 Ave & W 41 St', 'W 22 St & 10 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 22 St & 8 Ave'), 1),
#  (('11 Ave & W 41 St', 'W 24 St & 7 Ave'), 6),
#  (('11 Ave & W 41 St', 'W 26 St & 10 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 26 St & 8 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 27 St & 7 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 31 St & 7 Ave'), 1),
#  (('11 Ave & W 41 St', 'W 34 St & 11 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 37 St & 10 Ave'), 1),
#  (('11 Ave & W 41 St', 'W 37 St & 5 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 38 St & 8 Ave'), 17),
#  (('11 Ave & W 41 St', 'W 39 St & 9 Ave'), 7),
#  (('11 Ave & W 41 St', 'W 41 St & 8 Ave'), 19),
#  (('11 Ave & W 41 St', 'W 42 St & 8 Ave'), 27),
#  (('11 Ave & W 41 St', 'W 43 St & 10 Ave'), 3),
#  (('11 Ave & W 41 St', 'W 43 St & 6 Ave'), 1),
#  (('11 Ave & W 41 St', 'W 44 St & 5 Ave'), 4),
#  (('11 Ave & W 41 St', 'W 45 St & 6 Ave'), 4),
#  (('11 Ave & W 41 St', 'W 45 St & 8 Ave'), 8),
#  (('11 Ave & W 41 St', 'W 46 St & 11 Ave'), 1),
#  (('11 Ave & W 41 St', 'W 47 St & 10 Ave'), 3),
#  (('11 Ave & W 41 St', 'W 49 St & 8 Ave'), 3),
#  (('11 Ave & W 41 St', 'W 52 St & 11 Ave'), 6),
#  (('11 Ave & W 41 St', 'W 52 St & 5 Ave'), 3),
#  (('11 Ave & W 41 St', 'W 52 St & 9 Ave'), 6),
#  (('11 Ave & W 41 St', 'W 53 St & 10 Ave'), 5),
#  (('11 Ave & W 41 St', 'W 56 St & 10 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 56 St & 6 Ave'), 2),
#  (('11 Ave & W 41 St', 'W 59 St & 10 Ave'), 1),
#  (('11 Ave & W 41 St', 'W Houston St & Hudson St'), 2),
#  (('11 Ave & W 41 St', 'Washington St & Gansevoort St'), 1),
#  (('11 Ave & W 41 St', 'Watts St & Greenwich St'), 1),
#  (('11 Ave & W 41 St', 'West St & Chambers St'), 2),
#  (('11 Ave & W 59 St', '12 Ave & W 40 St'), 2),
#  (('11 Ave & W 59 St', '2 Ave & E 58 St'), 1),
#  (('11 Ave & W 59 St', '5 Ave & E 29 St'), 1),
#  (('11 Ave & W 59 St', '6 Ave & Canal St'), 3),
#  (('11 Ave & W 59 St', '8 Ave & W 31 St'), 8),
#  (('11 Ave & W 59 St', '8 Ave & W 33 St'), 10),
#  (('11 Ave & W 59 St', '8 Ave & W 52 St'), 1),
#  (('11 Ave & W 59 St', '9 Ave & W 22 St'), 3),
#  (('11 Ave & W 59 St', '9 Ave & W 45 St'), 2),
#  (('11 Ave & W 59 St', 'Barclay St & Church St'), 1),
#  (('11 Ave & W 59 St', 'Barrow St & Hudson St'), 4),
#  (('11 Ave & W 59 St', 'Broadway & W 32 St'), 1),
#  (('11 Ave & W 59 St', 'Broadway & W 41 St'), 1),
#  (('11 Ave & W 59 St', 'Broadway & W 51 St'), 8),
#  (('11 Ave & W 59 St', 'Broadway & W 53 St'), 3),
#  (('11 Ave & W 59 St', 'Broadway & W 58 St'), 9),
#  (('11 Ave & W 59 St', 'Broadway & W 60 St'), 12),
#  (('11 Ave & W 59 St', 'Central Park S & 6 Ave'), 2),
#  (('11 Ave & W 59 St', 'Centre St & Worth St'), 1),
#  (('11 Ave & W 59 St', 'Christopher St & Greenwich St'), 1),
#  (('11 Ave & W 59 St', 'E 20 St & FDR Drive'), 3),
#  (('11 Ave & W 59 St', 'E 33 St & 2 Ave'), 1),
#  (('11 Ave & W 59 St', 'E 39 St & 2 Ave'), 3),
#  (('11 Ave & W 59 St', 'E 39 St & 3 Ave'), 1),
#  (('11 Ave & W 59 St', 'E 40 St & 5 Ave'), 1),
#  (('11 Ave & W 59 St', 'E 47 St & Park Ave'), 4),
#  (('11 Ave & W 59 St', 'E 48 St & 3 Ave'), 2),
#  (('11 Ave & W 59 St', 'E 51 St & Lexington Ave'), 1),
#  (('11 Ave & W 59 St', 'E 53 St & Madison Ave'), 4),
#  (('11 Ave & W 59 St', 'E 56 St & Madison Ave'), 3),
#  (('11 Ave & W 59 St', 'E 58 St & 3 Ave'), 1),
#  (('11 Ave & W 59 St', 'E 59 St & Sutton Pl'), 1),
#  (('11 Ave & W 59 St', 'E 6 St & Avenue B'), 1),
#  (('11 Ave & W 59 St', 'E 7 St & Avenue A'), 1),
#  (('11 Ave & W 59 St', 'Grand Army Plaza & Central Park S'), 11),
#  (('11 Ave & W 59 St', 'Great Jones St'), 1),
#  (('11 Ave & W 59 St', 'Greenwich St & N Moore St'), 1),
#  (('11 Ave & W 59 St', 'Laight St & Hudson St'), 1),
#  (('11 Ave & W 59 St', 'Leonard St & Church St'), 1),
#  (('11 Ave & W 59 St', 'Lexington Ave & E 24 St'), 3),
#  (('11 Ave & W 59 St', 'Lispenard St & Broadway'), 1),
#  (('11 Ave & W 59 St', 'Perry St & Bleecker St'), 1),
#  (('11 Ave & W 59 St', 'Vesey Pl & River Terrace'), 3),
#  (('11 Ave & W 59 St', 'W 13 St & 6 Ave'), 2),
#  (('11 Ave & W 59 St', 'W 16 St & The High Line'), 1),
#  (('11 Ave & W 59 St', 'W 20 St & 11 Ave'), 4),
#  (('11 Ave & W 59 St', 'W 20 St & 8 Ave'), 2),
#  (('11 Ave & W 59 St', 'W 21 St & 6 Ave'), 1),
#  (('11 Ave & W 59 St', 'W 22 St & 8 Ave'), 5),
#  (('11 Ave & W 59 St', 'W 25 St & 6 Ave'), 2),
#  (('11 Ave & W 59 St', 'W 26 St & 10 Ave'), 3),
#  (('11 Ave & W 59 St', 'W 29 St & 9 Ave'), 2),
#  (('11 Ave & W 59 St', 'W 34 St & 11 Ave'), 2),
#  (('11 Ave & W 59 St', 'W 37 St & 10 Ave'), 1),
#  (('11 Ave & W 59 St', 'W 38 St & 8 Ave'), 1),
#  (('11 Ave & W 59 St', 'W 39 St & 9 Ave'), 3),
#  (('11 Ave & W 59 St', 'W 4 St & 7 Ave S'), 4),
#  (('11 Ave & W 59 St', 'W 41 St & 8 Ave'), 6),
#  (('11 Ave & W 59 St', 'W 42 St & 8 Ave'), 12),
#  (('11 Ave & W 59 St', 'W 43 St & 10 Ave'), 8),
#  (('11 Ave & W 59 St', 'W 45 St & 6 Ave'), 1),
#  (('11 Ave & W 59 St', 'W 45 St & 8 Ave'), 3),
#  (('11 Ave & W 59 St', 'W 46 St & 11 Ave'), 2),
#  (('11 Ave & W 59 St', 'W 47 St & 10 Ave'), 9),
#  (('11 Ave & W 59 St', 'W 51 St & 6 Ave'), 3),
#  (('11 Ave & W 59 St', 'W 52 St & 5 Ave'), 7),
#  (('11 Ave & W 59 St', 'W 52 St & 9 Ave'), 4),
#  (('11 Ave & W 59 St', 'W 53 St & 10 Ave'), 3),
#  (('11 Ave & W 59 St', 'W 56 St & 10 Ave'), 1),
#  (('11 Ave & W 59 St', 'W 56 St & 6 Ave'), 4),
#  (('11 Ave & W 59 St', 'W Broadway & Spring St'), 1),
#  (('11 Ave & W 59 St', 'W Houston St & Hudson St'), 1),
#  (('11 Ave & W 59 St', 'Warren St & Church St'), 1),
#  (('11 Ave & W 59 St', 'Washington Pl & 6 Ave'), 2),
#  (('11 Ave & W 59 St', 'Washington St & Gansevoort St'), 2),
#  (('11 Ave & W 59 St', 'Watts St & Greenwich St'), 3),
#  (('11 Ave & W 59 St', 'West St & Chambers St'), 1),
#  (('11 Ave & W 59 St', 'William St & Pine St'), 1),
#  (('12 Ave & W 40 St', '12 Ave & W 40 St'), 2),
#  (('12 Ave & W 40 St', '2 Ave & E 31 St'), 1),
#  (('12 Ave & W 40 St', '5 Ave & E 29 St'), 1),
#  (('12 Ave & W 40 St', '6 Ave & Canal St'), 2),
#  (('12 Ave & W 40 St', '8 Ave & W 31 St'), 1),
#  (('12 Ave & W 40 St', '8 Ave & W 33 St'), 8),
#  (('12 Ave & W 40 St', '8 Ave & W 52 St'), 3),
#  (('12 Ave & W 40 St', '9 Ave & W 16 St'), 10),
#  (('12 Ave & W 40 St', 'Allen St & E Houston St'), 1),
#  (('12 Ave & W 40 St', 'Bank St & Hudson St'), 1),
#  (('12 Ave & W 40 St', 'Barrow St & Hudson St'), 2),
#  (('12 Ave & W 40 St', 'Broadway & Battery Pl'), 1),
#  (('12 Ave & W 40 St', 'Broadway & E 22 St'), 1),
#  (('12 Ave & W 40 St', 'Broadway & W 24 St'), 1),
#  (('12 Ave & W 40 St', 'Broadway & W 32 St'), 2),
#  (('12 Ave & W 40 St', 'Broadway & W 39 St'), 1),
#  (('12 Ave & W 40 St', 'Broadway & W 41 St'), 2),
#  (('12 Ave & W 40 St', 'Broadway & W 49 St'), 3),
#  (('12 Ave & W 40 St', 'Broadway & W 51 St'), 2),
#  (('12 Ave & W 40 St', 'Broadway & W 53 St'), 8),
#  (('12 Ave & W 40 St', 'Broadway & W 55 St'), 4),
#  (('12 Ave & W 40 St', 'Broadway & W 58 St'), 1),
#  (('12 Ave & W 40 St', 'Bus Slip & State St'), 4),
#  (('12 Ave & W 40 St', 'Carmine St & 6 Ave'), 1),
#  (('12 Ave & W 40 St', 'Central Park S & 6 Ave'), 1),
#  (('12 Ave & W 40 St', 'Christopher St & Greenwich St'), 1),
#  (('12 Ave & W 40 St', 'Cliff St & Fulton St'), 1),
#  (('12 Ave & W 40 St', 'Duane St & Greenwich St'), 2),
#  (('12 Ave & W 40 St', 'E 16 St & 5 Ave'), 1),
#  (('12 Ave & W 40 St', 'E 23 St & 1 Ave'), 1),
#  (('12 Ave & W 40 St', 'E 24 St & Park Ave S'), 3),
#  (('12 Ave & W 40 St', 'E 25 St & 1 Ave'), 1),
#  (('12 Ave & W 40 St', 'E 25 St & 2 Ave'), 5),
#  (('12 Ave & W 40 St', 'E 3 St & 1 Ave'), 1),
#  (('12 Ave & W 40 St', 'E 30 St & Park Ave S'), 1),
#  (('12 Ave & W 40 St', 'E 43 St & Vanderbilt Ave'), 9),
#  (('12 Ave & W 40 St', 'E 48 St & Madison Ave'), 2),
#  (('12 Ave & W 40 St', 'E 53 St & Lexington Ave'), 2),
#  (('12 Ave & W 40 St', 'E 53 St & Madison Ave'), 1),
#  (('12 Ave & W 40 St', 'E 55 St & 2 Ave'), 1),
#  (('12 Ave & W 40 St', 'E 55 St & Lexington Ave'), 1),
#  (('12 Ave & W 40 St', 'E 56 St & Madison Ave'), 2),
#  (('12 Ave & W 40 St', 'Fulton St & Clermont Ave'), 1),
#  (('12 Ave & W 40 St', 'Grand Army Plaza & Central Park S'), 1),
#  (('12 Ave & W 40 St', 'Greenwich Ave & 8 Ave'), 1),
#  (('12 Ave & W 40 St', 'Greenwich St & N Moore St'), 1),
#  (('12 Ave & W 40 St', 'Harrison St & Hudson St'), 1),
#  (('12 Ave & W 40 St', 'Howard St & Centre St'), 1),
#  (('12 Ave & W 40 St', 'LaGuardia Pl & W 3 St'), 1),
#  (('12 Ave & W 40 St', 'Lexington Ave & E 24 St'), 2),
#  (('12 Ave & W 40 St', 'MacDougal St & Prince St'), 2),
#  (('12 Ave & W 40 St', 'Mercer St & Bleecker St'), 1),
#  (('12 Ave & W 40 St', 'Pearl St & Hanover Square'), 1),
#  (('12 Ave & W 40 St', 'Perry St & Bleecker St'), 2),
#  (('12 Ave & W 40 St', 'Pershing Square North'), 2),
#  (('12 Ave & W 40 St', 'South End Ave & Liberty St'), 2),
#  (('12 Ave & W 40 St', 'Vesey Pl & River Terrace'), 5),
#  (('12 Ave & W 40 St', 'W 13 St & 6 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 14 St & The High Line'), 1),
#  (('12 Ave & W 40 St', 'W 15 St & 7 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 16 St & The High Line'), 3),
#  (('12 Ave & W 40 St', 'W 17 St & 8 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 18 St & 6 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 20 St & 11 Ave'), 7),
#  (('12 Ave & W 40 St', 'W 20 St & 7 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 21 St & 6 Ave'), 3),
#  (('12 Ave & W 40 St', 'W 22 St & 10 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 22 St & 8 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 24 St & 7 Ave'), 3),
#  (('12 Ave & W 40 St', 'W 26 St & 10 Ave'), 3),
#  (('12 Ave & W 40 St', 'W 26 St & 8 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 31 St & 7 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 37 St & 10 Ave'), 4),
#  (('12 Ave & W 40 St', 'W 38 St & 8 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 39 St & 9 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 42 St & 8 Ave'), 9),
#  (('12 Ave & W 40 St', 'W 45 St & 8 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 46 St & 11 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 47 St & 10 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 49 St & 8 Ave'), 3),
#  (('12 Ave & W 40 St', 'W 52 St & 11 Ave'), 6),
#  (('12 Ave & W 40 St', 'W 52 St & 5 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 52 St & 9 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 53 St & 10 Ave'), 1),
#  (('12 Ave & W 40 St', 'W 56 St & 10 Ave'), 2),
#  (('12 Ave & W 40 St', 'W 56 St & 6 Ave'), 4),
#  (('12 Ave & W 40 St', 'W 59 St & 10 Ave'), 2),
#  (('12 Ave & W 40 St', 'W Houston St & Hudson St'), 7),
#  (('12 Ave & W 40 St', 'Washington Square E'), 1),
#  (('12 Ave & W 40 St', 'Washington St & Gansevoort St'), 1),
#  (('12 Ave & W 40 St', 'West St & Chambers St'), 2),
#  (('2 Ave & E 31 St', '2 Ave & E 31 St'), 7),
#  (('2 Ave & E 31 St', '2 Ave & E 58 St'), 2),
#  (('2 Ave & E 31 St', '5 Ave & E 29 St'), 7),
#  (('2 Ave & E 31 St', '6 Ave & W 33 St'), 8),
#  (('2 Ave & E 31 St', '8 Ave & W 31 St'), 10),
#  (('2 Ave & E 31 St', '8 Ave & W 33 St'), 8),
#  (('2 Ave & E 31 St', '8 Ave & W 52 St'), 1),
#  (('2 Ave & E 31 St', '9 Ave & W 16 St'), 1),
#  (('2 Ave & E 31 St', '9 Ave & W 18 St'), 2),
#  (('2 Ave & E 31 St', '9 Ave & W 22 St'), 2),
#  (('2 Ave & E 31 St', '9 Ave & W 45 St'), 1),
#  (('2 Ave & E 31 St', 'Allen St & E Houston St'), 2),
#  (('2 Ave & E 31 St', 'Allen St & Hester St'), 1),
#  (('2 Ave & E 31 St', 'Avenue D & E 3 St'), 1),
#  (('2 Ave & E 31 St', 'Bialystoker Pl & Delancey St'), 2),
#  (('2 Ave & E 31 St', 'Broadway & E 22 St'), 4),
#  (('2 Ave & E 31 St', 'Broadway & W 24 St'), 1),
#  (('2 Ave & E 31 St', 'Broadway & W 29 St'), 8),
#  (('2 Ave & E 31 St', 'Broadway & W 32 St'), 16),
#  (('2 Ave & E 31 St', 'Broadway & W 36 St'), 4),
#  (('2 Ave & E 31 St', 'Broadway & W 41 St'), 2),
#  (('2 Ave & E 31 St', 'Broadway & W 49 St'), 2),
#  (('2 Ave & E 31 St', 'Broadway & W 51 St'), 2),
#  (('2 Ave & E 31 St', 'Broadway & W 53 St'), 1),
#  (('2 Ave & E 31 St', 'Carmine St & 6 Ave'), 1),
#  (('2 Ave & E 31 St', 'Catherine St & Monroe St'), 1),
#  (('2 Ave & E 31 St', 'Cleveland Pl & Spring St'), 4),
#  (('2 Ave & E 31 St', 'Clinton St & Tillary St'), 1),
#  (('2 Ave & E 31 St', 'Columbia St & Rivington St'), 1),
#  (('2 Ave & E 31 St', 'Division St & Bowery'), 1),
#  (('2 Ave & E 31 St', 'E 10 St & 5 Ave'), 1),
#  (('2 Ave & E 31 St', 'E 10 St & Avenue A'), 1),
#  (('2 Ave & E 31 St', 'E 11 St & 1 Ave'), 6),
#  (('2 Ave & E 31 St', 'E 11 St & 2 Ave'), 12),
#  (('2 Ave & E 31 St', 'E 11 St & Broadway'), 1),
#  (('2 Ave & E 31 St', 'E 12 St & 3 Ave'), 5),
#  (('2 Ave & E 31 St', 'E 13 St & Avenue A'), 1),
#  (('2 Ave & E 31 St', 'E 14 St & Avenue B'), 5),
#  (('2 Ave & E 31 St', 'E 15 St & 3 Ave'), 8),
#  (('2 Ave & E 31 St', 'E 16 St & 5 Ave'), 3),
#  (('2 Ave & E 31 St', 'E 16 St & Irving Pl'), 3),
#  (('2 Ave & E 31 St', 'E 17 St & Broadway'), 8),
#  (('2 Ave & E 31 St', 'E 19 St & 3 Ave'), 2),
#  (('2 Ave & E 31 St', 'E 2 St & 2 Ave'), 2),
#  (('2 Ave & E 31 St', 'E 2 St & Avenue B'), 2),
#  (('2 Ave & E 31 St', 'E 20 St & 2 Ave'), 6),
#  (('2 Ave & E 31 St', 'E 20 St & FDR Drive'), 4),
#  (('2 Ave & E 31 St', 'E 20 St & Park Ave'), 8),
#  (('2 Ave & E 31 St', 'E 23 St & 1 Ave'), 13),
#  (('2 Ave & E 31 St', 'E 24 St & Park Ave S'), 7),
#  (('2 Ave & E 31 St', 'E 25 St & 1 Ave'), 17),
#  (('2 Ave & E 31 St', 'E 25 St & 2 Ave'), 11),
#  (('2 Ave & E 31 St', 'E 27 St & 1 Ave'), 4),
#  (('2 Ave & E 31 St', 'E 3 St & 1 Ave'), 1),
#  (('2 Ave & E 31 St', 'E 30 St & Park Ave S'), 7),
#  (('2 Ave & E 31 St', 'E 31 St & 3 Ave'), 5),
#  (('2 Ave & E 31 St', 'E 32 St & Park Ave'), 30),
#  (('2 Ave & E 31 St', 'E 33 St & 2 Ave'), 2),
#  (('2 Ave & E 31 St', 'E 33 St & 5 Ave'), 9),
#  (('2 Ave & E 31 St', 'E 37 St & Lexington Ave'), 7),
#  (('2 Ave & E 31 St', 'E 39 St & 2 Ave'), 19),
#  (('2 Ave & E 31 St', 'E 39 St & 3 Ave'), 9),
#  (('2 Ave & E 31 St', 'E 4 St & 2 Ave'), 3),
#  (('2 Ave & E 31 St', 'E 40 St & 5 Ave'), 2),
#  (('2 Ave & E 31 St', 'E 43 St & 2 Ave'), 3),
#  (('2 Ave & E 31 St', 'E 47 St & 1 Ave'), 3),
#  (('2 Ave & E 31 St', 'E 47 St & 2 Ave'), 1),
#  (('2 Ave & E 31 St', 'E 47 St & Park Ave'), 2),
#  (('2 Ave & E 31 St', 'E 48 St & 3 Ave'), 2),
#  (('2 Ave & E 31 St', 'E 48 St & Madison Ave'), 1),
#  (('2 Ave & E 31 St', 'E 51 St & 1 Ave'), 3),
#  (('2 Ave & E 31 St', 'E 52 St & 2 Ave'), 2),
#  (('2 Ave & E 31 St', 'E 55 St & 2 Ave'), 2),
#  (('2 Ave & E 31 St', 'E 56 St & 3 Ave'), 1),
#  (('2 Ave & E 31 St', 'E 58 St & 3 Ave'), 5),
#  (('2 Ave & E 31 St', 'E 59 St & Sutton Pl'), 3),
#  (('2 Ave & E 31 St', 'E 6 St & Avenue B'), 3),
#  (('2 Ave & E 31 St', 'E 7 St & Avenue A'), 2),
#  (('2 Ave & E 31 St', 'E 9 St & Avenue C'), 3),
#  (('2 Ave & E 31 St', 'Elizabeth St & Hester St'), 2),
#  (('2 Ave & E 31 St', 'Forsyth St & Broome St'), 1),
#  (('2 Ave & E 31 St', 'Forsyth St & Canal St'), 2),
#  (('2 Ave & E 31 St', 'Front St & Maiden Ln'), 1),
#  (('2 Ave & E 31 St', 'Grand St & Havemeyer St'), 1),
#  (('2 Ave & E 31 St', 'Greenwich Ave & Charles St'), 1),
#  (('2 Ave & E 31 St', 'Hicks St & Montague St'), 1),
#  (('2 Ave & E 31 St', 'Howard St & Centre St'), 1),
#  (('2 Ave & E 31 St', 'LaGuardia Pl & W 3 St'), 3),
#  (('2 Ave & E 31 St', 'Lafayette Ave & Fort Greene Pl'), 1),
#  (('2 Ave & E 31 St', 'Lafayette St & E 8 St'), 2),
#  (('2 Ave & E 31 St', 'Lafayette St & Jersey St'), 1),
#  (('2 Ave & E 31 St', 'Lexington Ave & E 24 St'), 3),
#  (('2 Ave & E 31 St', 'MacDougal St & Prince St'), 2),
#  (('2 Ave & E 31 St', 'Mercer St & Bleecker St'), 5),
#  (('2 Ave & E 31 St', 'Mott St & Prince St'), 1),
#  (('2 Ave & E 31 St', 'Norfolk St & Broome St'), 1),
#  (('2 Ave & E 31 St', 'Pershing Square North'), 9),
#  (('2 Ave & E 31 St', 'Pershing Square South'), 8),
#  (('2 Ave & E 31 St', 'Pike St & E Broadway'), 1),
#  (('2 Ave & E 31 St', 'Reade St & Broadway'), 1),
#  (('2 Ave & E 31 St', 'Rivington St & Ridge St'), 2),
#  (('2 Ave & E 31 St', 'St Marks Pl & 1 Ave'), 5),
#  (('2 Ave & E 31 St', 'St Marks Pl & 2 Ave'), 9),
#  (('2 Ave & E 31 St', 'University Pl & E 14 St'), 2),
#  (('2 Ave & E 31 St', 'W 13 St & 6 Ave'), 2),
#  (('2 Ave & E 31 St', 'W 15 St & 7 Ave'), 2),
#  (('2 Ave & E 31 St', 'W 16 St & The High Line'), 4),
#  (('2 Ave & E 31 St', 'W 17 St & 8 Ave'), 4),
#  (('2 Ave & E 31 St', 'W 18 St & 6 Ave'), 2),
#  (('2 Ave & E 31 St', 'W 20 St & 11 Ave'), 1),
#  (('2 Ave & E 31 St', 'W 20 St & 7 Ave'), 3),
#  (('2 Ave & E 31 St', 'W 21 St & 6 Ave'), 3),
#  (('2 Ave & E 31 St', 'W 22 St & 8 Ave'), 1),
#  (('2 Ave & E 31 St', 'W 24 St & 7 Ave'), 3),
#  (('2 Ave & E 31 St', 'W 25 St & 6 Ave'), 9),
#  (('2 Ave & E 31 St', 'W 26 St & 8 Ave'), 4),
#  (('2 Ave & E 31 St', 'W 29 St & 9 Ave'), 1),
#  (('2 Ave & E 31 St', 'W 31 St & 7 Ave'), 29),
#  (('2 Ave & E 31 St', 'W 33 St & 7 Ave'), 22),
#  (('2 Ave & E 31 St', 'W 34 St & 11 Ave'), 1),
#  (('2 Ave & E 31 St', 'W 37 St & 10 Ave'), 1),
#  (('2 Ave & E 31 St', 'W 37 St & 5 Ave'), 5),
#  (('2 Ave & E 31 St', 'W 38 St & 8 Ave'), 4),
#  (('2 Ave & E 31 St', 'W 39 St & 9 Ave'), 4),
#  (('2 Ave & E 31 St', 'W 41 St & 8 Ave'), 11),
#  (('2 Ave & E 31 St', 'W 43 St & 6 Ave'), 6),
#  (('2 Ave & E 31 St', 'W 45 St & 6 Ave'), 2),
#  (('2 Ave & E 31 St', 'W 47 St & 10 Ave'), 2),
#  (('2 Ave & E 31 St', 'W 51 St & 6 Ave'), 1),
#  (('2 Ave & E 31 St', 'W 52 St & 5 Ave'), 3),
#  (('2 Ave & E 31 St', 'W Houston St & Hudson St'), 1),
#  (('2 Ave & E 31 St', 'Warren St & Church St'), 1),
#  (('2 Ave & E 31 St', 'Washington Pl & 6 Ave'), 2),
#  (('2 Ave & E 31 St', 'Washington Pl & Broadway'), 3),
#  (('2 Ave & E 31 St', 'Washington Square E'), 1),
#  (('2 Ave & E 58 St', '8 Ave & W 31 St'), 1),
#  (('2 Ave & E 58 St', '8 Ave & W 33 St'), 2),
#  (('2 Ave & E 58 St', 'Allen St & E Houston St'), 1),
#  (('2 Ave & E 58 St', 'Broadway & E 14 St'), 1),
#  (('2 Ave & E 58 St', 'Broadway & W 36 St'), 1),
#  (('2 Ave & E 58 St', 'Broadway & W 51 St'), 2),
#  (('2 Ave & E 58 St', 'Broadway & W 58 St'), 1),
#  (('2 Ave & E 58 St', 'Broadway & W 60 St'), 4),
#  (('2 Ave & E 58 St', 'E 10 St & Avenue A'), 1),
#  (('2 Ave & E 58 St', 'E 11 St & 2 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 12 St & 3 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 15 St & 3 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 16 St & 5 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 20 St & 2 Ave'), 10),
#  (('2 Ave & E 58 St', 'E 23 St & 1 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 24 St & Park Ave S'), 1),
#  (('2 Ave & E 58 St', 'E 25 St & 1 Ave'), 2),
#  (('2 Ave & E 58 St', 'E 27 St & 1 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 33 St & 2 Ave'), 2),
#  (('2 Ave & E 58 St', 'E 37 St & Lexington Ave'), 3),
#  (('2 Ave & E 58 St', 'E 39 St & 2 Ave'), 3),
#  (('2 Ave & E 58 St', 'E 39 St & 3 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 40 St & 5 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 43 St & 2 Ave'), 2),
#  (('2 Ave & E 58 St', 'E 43 St & Vanderbilt Ave'), 2),
#  (('2 Ave & E 58 St', 'E 45 St & 3 Ave'), 2),
#  (('2 Ave & E 58 St', 'E 47 St & 1 Ave'), 3),
#  (('2 Ave & E 58 St', 'E 47 St & 2 Ave'), 4),
#  (('2 Ave & E 58 St', 'E 47 St & Park Ave'), 1),
#  (('2 Ave & E 58 St', 'E 48 St & 3 Ave'), 2),
#  (('2 Ave & E 58 St', 'E 48 St & Madison Ave'), 2),
#  (('2 Ave & E 58 St', 'E 5 St & Avenue C'), 1),
#  (('2 Ave & E 58 St', 'E 52 St & 2 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 53 St & Lexington Ave'), 2),
#  (('2 Ave & E 58 St', 'E 53 St & Madison Ave'), 4),
#  (('2 Ave & E 58 St', 'E 55 St & 2 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 55 St & Lexington Ave'), 2),
#  (('2 Ave & E 58 St', 'E 56 St & 3 Ave'), 1),
#  (('2 Ave & E 58 St', 'E 56 St & Madison Ave'), 1),
#  (('2 Ave & E 58 St', 'E 9 St & Avenue C'), 1),
#  (('2 Ave & E 58 St', 'Grand Army Plaza & Central Park S'), 1),
#  (('2 Ave & E 58 St', 'Lafayette St & Jersey St'), 1),
#  (('2 Ave & E 58 St', 'Lexington Ave & E 24 St'), 2),
#  (('2 Ave & E 58 St', 'Norfolk St & Broome St'), 1),
#  (('2 Ave & E 58 St', 'Pershing Square North'), 1),
#  (('2 Ave & E 58 St', 'Pershing Square South'), 3),
#  (('2 Ave & E 58 St', 'St Marks Pl & 2 Ave'), 1),
#  (('2 Ave & E 58 St', 'W 13 St & 6 Ave'), 1),
#  (('2 Ave & E 58 St', 'W 20 St & 11 Ave'), 1),
#  (('2 Ave & E 58 St', 'W 21 St & 6 Ave'), 3),
#  (('2 Ave & E 58 St', 'W 22 St & 8 Ave'), 1),
#  (('2 Ave & E 58 St', 'W 25 St & 6 Ave'), 1),
#  (('2 Ave & E 58 St', 'W 31 St & 7 Ave'), 4),
#  (('2 Ave & E 58 St', 'W 33 St & 7 Ave'), 2),
#  (('2 Ave & E 58 St', 'W 37 St & 5 Ave'), 1),
#  (('2 Ave & E 58 St', 'W 41 St & 8 Ave'), 4),
#  (('2 Ave & E 58 St', 'W 43 St & 6 Ave'), 3),
#  (('2 Ave & E 58 St', 'W 44 St & 5 Ave'), 1),
#  (('2 Ave & E 58 St', 'W 45 St & 8 Ave'), 2),
#  (('2 Ave & E 58 St', 'W 49 St & 8 Ave'), 2),
#  (('2 Ave & E 58 St', 'W 52 St & 5 Ave'), 2),
#  (('2 Ave & E 58 St', 'W 56 St & 6 Ave'), 3),
#  (('2 Ave & E 58 St', 'Washington Pl & 6 Ave'), 1),
#  (('3 Ave & Schermerhorn St', '5 Ave & E 29 St'), 1),
#  (('3 Ave & Schermerhorn St', '6 Ave & Canal St'), 1),
#  (('3 Ave & Schermerhorn St', 'Allen St & Hester St'), 1),
#  (('3 Ave & Schermerhorn St', 'Bond St & Schermerhorn St'), 4),
#  (('3 Ave & Schermerhorn St', 'Broadway & E 22 St'), 1),
#  (('3 Ave & Schermerhorn St', 'Broadway & W 24 St'), 1),
#  (('3 Ave & Schermerhorn St', 'Broadway & W 29 St'), 2),
#  (('3 Ave & Schermerhorn St', 'Cadman Plaza West & Montague St'), 1),
#  (('3 Ave & Schermerhorn St', 'Carlton Ave & Park Ave'), 1),
#  (('3 Ave & Schermerhorn St', 'Clermont Ave & Park Ave'), 1),
#  (('3 Ave & Schermerhorn St', 'Cleveland Pl & Spring St'), 2),
#  (('3 Ave & Schermerhorn St', 'Cliff St & Fulton St'), 1),
#  (('3 Ave & Schermerhorn St', 'Concord St & Bridge St'), 1),
#  (('3 Ave & Schermerhorn St', 'Cumberland St & Lafayette Ave'), 1),
#  (('3 Ave & Schermerhorn St', 'Dean St & 4 Ave'), 1),
#  (('3 Ave & Schermerhorn St', 'Forsyth St & Canal St'), 1),
#  (('3 Ave & Schermerhorn St', 'Henry St & Atlantic Ave'), 1),
#  (('3 Ave & Schermerhorn St', 'Jay St & Tech Pl'), 1),
#  (('3 Ave & Schermerhorn St', 'Johnson St & Gold St'), 1),
#  (('3 Ave & Schermerhorn St', 'Joralemon St & Adams St'), 1),
#  (('3 Ave & Schermerhorn St', 'Old Fulton St'), 1),
#  (('3 Ave & Schermerhorn St', 'State St & Smith St'), 6),
#  (('3 Ave & Schermerhorn St', 'Willoughby St & Fleet St'), 1),
#  (('3 Ave & Schermerhorn St', 'York St & Jay St'), 1),
#  (('5 Ave & E 29 St', '5 Ave & E 29 St'), 3),
#  (('5 Ave & E 29 St', '6 Ave & W 33 St'), 4),
#  (('5 Ave & E 29 St', '8 Ave & W 31 St'), 9),
#  (('5 Ave & E 29 St', '8 Ave & W 33 St'), 2),
#  (('5 Ave & E 29 St', '9 Ave & W 16 St'), 4),
#  (('5 Ave & E 29 St', '9 Ave & W 18 St'), 1),
#  (('5 Ave & E 29 St', '9 Ave & W 22 St'), 3),
#  (('5 Ave & E 29 St', '9 Ave & W 45 St'), 4),
#  (('5 Ave & E 29 St', 'Adelphi St & Myrtle Ave'), 1),
#  (('5 Ave & E 29 St', 'Bank St & Hudson St'), 1),
#  (('5 Ave & E 29 St', 'Bond St & Schermerhorn St'), 1),
#  (('5 Ave & E 29 St', 'Broadway & E 14 St'), 1),
#  (('5 Ave & E 29 St', 'Broadway & E 22 St'), 9),
#  (('5 Ave & E 29 St', 'Broadway & W 24 St'), 6),
#  (('5 Ave & E 29 St', 'Broadway & W 29 St'), 1),
#  (('5 Ave & E 29 St', 'Broadway & W 32 St'), 6),
#  (('5 Ave & E 29 St', 'Broadway & W 36 St'), 3),
#  (('5 Ave & E 29 St', 'Broadway & W 37 St'), 3),
#  (('5 Ave & E 29 St', 'Broadway & W 39 St'), 5),
#  (('5 Ave & E 29 St', 'Broadway & W 41 St'), 1),
#  (('5 Ave & E 29 St', 'Broadway & W 49 St'), 2),
#  (('5 Ave & E 29 St', 'Broadway & W 58 St'), 2),
#  (('5 Ave & E 29 St', 'Broadway & W 60 St'), 1),
#  (('5 Ave & E 29 St', 'E 10 St & 5 Ave'), 3),
#  (('5 Ave & E 29 St', 'E 10 St & Avenue A'), 2),
#  (('5 Ave & E 29 St', 'E 11 St & 1 Ave'), 2),
#  (('5 Ave & E 29 St', 'E 12 St & 3 Ave'), 4),
#  (('5 Ave & E 29 St', 'E 13 St & Avenue A'), 2),
#  (('5 Ave & E 29 St', 'E 14 St & Avenue B'), 2),
#  (('5 Ave & E 29 St', 'E 15 St & 3 Ave'), 1),
#  (('5 Ave & E 29 St', 'E 16 St & 5 Ave'), 8),
#  (('5 Ave & E 29 St', 'E 16 St & Irving Pl'), 3),
#  (('5 Ave & E 29 St', 'E 17 St & Broadway'), 6),
#  (('5 Ave & E 29 St', 'E 19 St & 3 Ave'), 3),
#  (('5 Ave & E 29 St', 'E 2 St & 2 Ave'), 4),
#  (('5 Ave & E 29 St', 'E 2 St & Avenue B'), 3),
#  (('5 Ave & E 29 St', 'E 20 St & 2 Ave'), 3),
#  (('5 Ave & E 29 St', 'E 20 St & FDR Drive'), 2),
#  (('5 Ave & E 29 St', 'E 20 St & Park Ave'), 1),
#  (('5 Ave & E 29 St', 'E 23 St & 1 Ave'), 5),
#  (('5 Ave & E 29 St', 'E 24 St & Park Ave S'), 5),
#  (('5 Ave & E 29 St', 'E 25 St & 1 Ave'), 5),
#  (('5 Ave & E 29 St', 'E 25 St & 2 Ave'), 6),
#  (('5 Ave & E 29 St', 'E 27 St & 1 Ave'), 4),
#  (('5 Ave & E 29 St', 'E 3 St & 1 Ave'), 1),
#  (('5 Ave & E 29 St', 'E 31 St & 3 Ave'), 3),
#  (('5 Ave & E 29 St', 'E 32 St & Park Ave'), 12),
#  (('5 Ave & E 29 St', 'E 33 St & 2 Ave'), 2),
#  (('5 Ave & E 29 St', 'E 33 St & 5 Ave'), 1),
#  (('5 Ave & E 29 St', 'E 39 St & 2 Ave'), 6),
#  (('5 Ave & E 29 St', 'E 39 St & 3 Ave'), 2),
#  (('5 Ave & E 29 St', 'E 40 St & 5 Ave'), 10),
#  (('5 Ave & E 29 St', 'E 43 St & 2 Ave'), 1),
#  (('5 Ave & E 29 St', 'E 43 St & Vanderbilt Ave'), 6),
#  (('5 Ave & E 29 St', 'E 48 St & 3 Ave'), 1),
#  (('5 Ave & E 29 St', 'E 48 St & Madison Ave'), 2),
#  (('5 Ave & E 29 St', 'E 5 St & Avenue C'), 4),
#  (('5 Ave & E 29 St', 'E 51 St & Lexington Ave'), 1),
#  (('5 Ave & E 29 St', 'E 53 St & Madison Ave'), 1),
#  (('5 Ave & E 29 St', 'E 55 St & 2 Ave'), 2),
#  (('5 Ave & E 29 St', 'E 56 St & 3 Ave'), 1),
#  (('5 Ave & E 29 St', 'E 6 St & Avenue B'), 1),
#  (('5 Ave & E 29 St', 'E 7 St & Avenue A'), 7),
#  (('5 Ave & E 29 St', 'Greenwich Ave & 8 Ave'), 7),
#  (('5 Ave & E 29 St', 'Greenwich Ave & Charles St'), 1),
#  (('5 Ave & E 29 St', 'Greenwich St & N Moore St'), 1),
#  (('5 Ave & E 29 St', 'Lafayette Ave & St James Pl'), 1),
#  ...]

# %% [markdown]
# ## Task 4 (2 points)
#
# Next, we would like to futher process the output from Task 3 to determine the station popularity among all of the station pairs that have 35 or more trips. The popularity of station is calculated as how many times it appears in the station pair lists for the top pairs. In other words, we would like to first filter the station pairs to only those that have 35 or more trips. Then, among these pairs, we count how many time each station appears and report back these counts. The output will be tuples, each consisting of the station name and a count. The expected output are included below. As illustrated, <i>W 41 St & 8 Ave</i> station is the most "popular" with 4 appearances. You are asked to fill in the <b>mapper4</b> and <b>reducer4</b> code block.

# %%
# first filter for o/d >35

def mapper4((station_pair, count)):
    if count>34:
        for name in sorted(station_pair):
            yield (name, 1)    
    
# reducer is to find "most popular names" - station name and count
    
def reducer4(k2v2):
    name, count = (k2v2)
    return (name, sum(count))
    
    
output4 = list(mr.run(output3, mapper4, reducer4))
output4
# Out:
# [('10 Ave & W 28 St', 1),
#  ('11 Ave & W 27 St', 2),
#  ('11 Ave & W 41 St', 1),
#  ('8 Ave & W 31 St', 3),
#  ('8 Ave & W 33 St', 1),
#  ('9 Ave & W 22 St', 1),
#  ('Adelphi St & Myrtle Ave', 1),
#  ('DeKalb Ave & Hudson Ave', 1),
#  ('E 10 St & Avenue A', 1),
#  ('E 24 St & Park Ave S', 2),
#  ('E 27 St & 1 Ave', 1),
#  ('E 32 St & Park Ave', 1),
#  ('E 33 St & 2 Ave', 2),
#  ('E 43 St & Vanderbilt Ave', 2),
#  ('E 47 St & Park Ave', 1),
#  ('E 6 St & Avenue B', 1),
#  ('E 7 St & Avenue A', 1),
#  ('Lafayette St & E 8 St', 3),
#  ('Pershing Square North', 1),
#  ('Pershing Square South', 2),
#  ('Vesey Pl & River Terrace', 1),
#  ('W 17 St & 8 Ave', 1),
#  ('W 20 St & 11 Ave', 2),
#  ('W 21 St & 6 Ave', 1),
#  ('W 26 St & 8 Ave', 1),
#  ('W 31 St & 7 Ave', 2),
#  ('W 33 St & 7 Ave', 2),
#  ('W 41 St & 8 Ave', 4),
#  ('West Thames St', 1)]

# %% [markdown]
# ## Task 5 (0 points)
#
# This is another example of showing how to use nested jobs and to put everything together, so no points are given. Basically, we can run Task 3 and Task 4 combined in just a single call.

# %%
with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output5 = list(mr.run(mr.run(reader, mapper3, reducer3), mapper4, reducer4))
output5
# Out:
# [('10 Ave & W 28 St', 1),
#  ('11 Ave & W 27 St', 2),
#  ('11 Ave & W 41 St', 1),
#  ('8 Ave & W 31 St', 3),
#  ('8 Ave & W 33 St', 1),
#  ('9 Ave & W 22 St', 1),
#  ('Adelphi St & Myrtle Ave', 1),
#  ('DeKalb Ave & Hudson Ave', 1),
#  ('E 10 St & Avenue A', 1),
#  ('E 24 St & Park Ave S', 2),
#  ('E 27 St & 1 Ave', 1),
#  ('E 32 St & Park Ave', 1),
#  ('E 33 St & 2 Ave', 2),
#  ('E 43 St & Vanderbilt Ave', 2),
#  ('E 47 St & Park Ave', 1),
#  ('E 6 St & Avenue B', 1),
#  ('E 7 St & Avenue A', 1),
#  ('Lafayette St & E 8 St', 3),
#  ('Pershing Square North', 1),
#  ('Pershing Square South', 2),
#  ('Vesey Pl & River Terrace', 1),
#  ('W 17 St & 8 Ave', 1),
#  ('W 20 St & 11 Ave', 2),
#  ('W 21 St & 6 Ave', 1),
#  ('W 26 St & 8 Ave', 1),
#  ('W 31 St & 7 Ave', 2),
#  ('W 33 St & 7 Ave', 2),
#  ('W 41 St & 8 Ave', 4),
#  ('West Thames St', 1)]

# %% [markdown]
# ## Task 6 (4 points)
#
# In this task, you are asked to compute the station that riders started the most at for each gender. In particular, what was the station name with the highest number of bike pickups for female riders, male riders and unknown riders.
#
# The output will be a list of tuples, each includes a gender label (as indicated below) and another tuple consisting of a station name, and the total number of trips started at that station for that gender. The expected output are included below. You are asked to fill in the code block with a series of MapReduce jobs, using your own mapper and reducer functions.
#
# The label mapping for the gender column in citibike.csv is: (Zero=<b>Unknown</b>; 1=<b>Male</b>; 2=<b>Female</b>)

# %%
def mapper1(row):
    for station in [row['start_station_name'], row['end_station_name']]:
        yield (station, 1)
        
    
def reducer1(k2v2):
    station, count = (k2v2)
    return (station,sum(count))

# %%
def mapper6(row):
    startstation, gender = row['start_station_name'], row['gender']
    if gender == '0':
        yield (('unknown', startstation), 1)
    elif gender =='1':
        yield (('male', startstation), 1)
    elif gender =='2':
        yield (('female', startstation), 1)
    
def reducer6(k2v2):
    stations, count = k2v2
    return (stations, sum(count))  

def mapper7(listA):
    location, count = listA
    gender, station = location
    yield (gender, (station, count))
    
def reducer7(k2v2):
    gender, stcount = k2v2
    return (gender, max(stcount, key = lambda item: item[1]))
     
with open('citibike.csv', 'r') as fi:
    reader = csv.DictReader(fi)
    output5 = list(mr.run(mr.run(reader, mapper6, reducer6), mapper7, reducer7))
output5
# Out:
# [('female', ('W 21 St & 6 Ave', 107)),
#  ('male', ('8 Ave & W 31 St', 488)),
#  ('unknown', ('Central Park S & 6 Ave', 32))]
